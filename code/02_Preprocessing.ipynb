# %% [markdown]
# <img src='http://imgur.com/1ZcRyrc.png' style='float: left; margin: 20px; height: 55px'>
#
#
# # DSI-SG-42 Capstone Project:
# ### Silent Echoes: From Hand Waves to Written Phrases

# %% [markdown]
# # 2.1 Preprocessing of Video Files
#
# Video files comes in different resolutions and fps values. We will have to process the files so that they are consistent for the model.
#
# In this notebook, we will be cropping the videos so that the clip will only show the action that represents the word. Following that, we will also be resizing the clips into a standardized format of `30 fps` and with a video dimension of `512 x 512 pixels`.

# %%
# import libraries
import os
import shutil
import logging
import cv2
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import mediapipe as mp
from collections import defaultdict

# Configure logging to write to a file
log_dir = ('../log_files')
if not os.path.exists(log_dir):
    os.makedirs(log_dir)

log_file = os.path.join(log_dir, 'preprocessing.log')

# Setup Logger
logger = logging.getLogger()  # Get the root logger
for handler in logger.handlers:  # Remove all old handlers
    logger.removeHandler(handler)


logging.basicConfig(
    level=logging.INFO,
    format = '%(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler(log_file),
        logging.StreamHandler()  
    ]
)


# set display settings
# %matplotlib inline
pd.set_option('display.width', 100000)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## 2.1 Import Data
#
# We will import the various csv files to get information of the start and end frames of the sign action.

# %%
# Recalling first 3 words that we will be modeling upon

first_three = ['please', 'sorry', 'hello']

# %%
# import train dataset
train_df = pd.read_csv('../data/msasl_train.csv')

print(train_df.head()) # inspect dataframe
# Out:
#   clean_text                                            file  label  height  width    fps  start   end                                  cleaned_url
# 0      hello  American Sign Language Learning the basics.mp4      0     360    640  29.97   1874  1903  https://www.youtube.com/watch?v=yG09SQB0Hds
# 1      hello                        Unit 1 Vocabulary(2).mp4      0     360    640  29.97    280   362  https://www.youtube.com/watch?v=7YYB3BEoksc
# 2      hello                        Unit 1 Vocabulary(2).mp4      0     360    640  29.97    250   277  https://www.youtube.com/watch?v=7YYB3BEoksc
# 3      hello                        ASL Vocabulary hello.mp4      0     360    640  29.97    110   150  https://www.youtube.com/watch?v=9jUuFHB2m4M
# 4      hello                        ASL Vocabulary hello.mp4      0     360    640  29.97     30    80  https://www.youtube.com/watch?v=9jUuFHB2m4M

# %%
# import test dataset
test_df = pd.read_csv('../data/msasl_test.csv')

print(test_df.head()) # inspect dataframe
# Out:
#   clean_text                               file  label  height  width    fps  start  end                                  cleaned_url
# 0      hello        ASL1 Class 48 New SIGNS.mp4      0     720   1280  29.97     84  150  https://www.youtube.com/watch?v=kVIt-qr5P2s
# 1      hello  ASL Top ASL Signs for Servers.mp4      0     360    360  29.97     11   51  https://www.youtube.com/watch?v=FBimL8-ND3E
# 2      hello       ASL3 Class 23 Vocabulary.mp4      0     720   1280  29.97     92  124  https://www.youtube.com/watch?v=eLpHf9bfdsI
# 3      hello        ASL1 Class 29 New SIGNS.mp4      0     720   1280  29.97    106  136  https://www.youtube.com/watch?v=H3eHAKpTF70
# 4      hello  ASL Top ASL Signs for Servers.mp4      0     360    360  29.97    101  161  https://www.youtube.com/watch?v=FBimL8-ND3E

# %%
# import validation dataset
val_df = pd.read_csv('../data/msasl_val.csv')

print(val_df.head()) # inspect dataframe
# Out:
#   clean_text                                              file  label  height  width    fps  start    end                                  cleaned_url
# 0      hello                                        Unit 1.mp4      0     360    640  29.97  12647  12830  https://www.youtube.com/watch?v=BEKUHzwnVO8
# 1      hello         Mr Miseners ASL lesson 1 vocab review.mp4      0     720   1280  30.00   2149   2263  https://www.youtube.com/watch?v=kZuJalsv_z0
# 2      hello                               Social Work Voc.mp4      0     720   1280  30.00      6     39  https://www.youtube.com/watch?v=V8DTIPK4QlU
# 3      hello                     ASL I - Unit 1 Vocabulary.mp4      0     720   1280  24.00   2240   2316  https://www.youtube.com/watch?v=2VB3WN8adyM
# 4      hello  Greetings  Answers in American Sign Language.mp4      0     360    640  29.97     14     73  https://www.youtube.com/watch?v=pD4QabDQr6M

# %%
# import wlasl dataset

wlasl_df = pd.read_csv('../data/wlasl.csv')

print(wlasl_df.head()) # inspect dataframe
# Out:
#   clean_text    file  fps  start   end
# 0      hello  27177_   25      1    -1
# 1      hello  27175_   25      1    -1
# 2      hello  27171_   25   1297  1343
# 3      hello  70017_   25   4842  4923
# 4      hello  68236_   25      1    36

# %% [markdown]
# All the datasets have been imported and looking good to continue. From this point on, we will be cropping the video to the timestamps given or the targeted frames.
#
# To standardize all video files, we will proceed to resize the video to `512 x 512 pixels` and limit the frames per second to `30` to ensure consistency.

# %% [markdown]
# As all the videos from the WL-ASL videos are already cropped we will leave it and continue to crop the videos from the MS-ASL.
#
# Below is an example of a video file from WL-ASL.

# %% [markdown]
# <video controls style = 'width: 65%; height: auto;'>
#     <source src='../videos/wlasl_data/hello/27172_.mp4' type='video/mp4'>
# </video>

# %% [markdown]
# ## 2.2 Video Cropping
#
# We need to clean the video files to clearly show **only** the signed action from a longer video clip from the Microsoft-ASL dataset videos that were downloaded from YouTube. Hence, we will create a function that crops the video according to the stipulated `start` and `end` frames. Followed by another function that will loop through each folder to crop the videos.

# %%
# define a crop function for a single video

def crop(video_path, start, stop, output_path):
    '''
    Crops a video and saves it to a new file.

    Args:
    video_path: Path to the source video file.
    start_sec: Start time of the desired clip in seconds.
    stop_sec: End time of the desired clip in seconds.
    output_path: Path to save the cropped video file.
    '''

    # Open the source video
    cap = cv2.VideoCapture(video_path)
    
    # break logic if the clip cannot be opened
    if not cap.isOpened():
        # print('Error opening video file: File not Available')
        logging.error('Error opening video file: File not Available %s', video_path)

        return

    # Get frames per second (fps) of the source video
    fps = cap.get(cv2.CAP_PROP_FPS)

    # Set the starting and stopping frames
    start_frame = int(start)
    stop_frame = int(stop)

    # Set video codec and create a VideoWriter object to write the video
    fourcc = cv2.VideoWriter_fourcc(*'mp4v') # video file is in mp4 format
    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)) # obtain the width of the clip
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT)) # obtain the height of the clip
    out = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height)) # write the file

    # Set the starting position of the video
    cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)

    # while loop to crop the file with the above conditions
    while True:

        # read the clip
        ret, frame = cap.read()
        if not ret:
            break

        # Get the current frame number and check if it is within the range
        current_frame = cap.get(cv2.CAP_PROP_POS_FRAMES)

        # break condition after the preassigned end time of action
        if current_frame > stop_frame:
            break

        # Write the frame to the output video
        out.write(frame)

    # Release everything when job is finished
    cap.release()
    out.release()
    #print(f'{video_path}: Video has been cropped and saved.')
    logging.info('Video has been cropped and saved. %s', video_path) # write log file

        

# define a function to crop all files within the same folder (action) 
def get_crop_video(word_label: str, save_folder:str, dataframe: pd.DataFrame):
    '''
    Crops videos based on a label and a DataFrame containing video information.

    Args:
    word_label: The label to filter videos by
    save_folder: The datset which the video will be found - train_data, test_data, val_data
    dataframe: A pandas DataFrame containing columns like 'file', 'start_time',
                'end_time', and 'clean_text'
    '''

    # temporary dataframe of target word/action
    label_df = dataframe[dataframe['clean_text'] == word_label]

    # Track the count of how many times each file is processed
    file_count = defaultdict(int)
    
    FOLDER_PATH = os.path.join('../videos/', save_folder ,  word_label) # folder of where the videos are stored
    OUTPUT_PATH = os.path.join(FOLDER_PATH,  'cropped_videos') # output of the video
    os.makedirs(OUTPUT_PATH, exist_ok=True)  # Create a output folder and ensure the output directory exists
    

    # Loop through videos and crop them
    for index, row in label_df.iterrows():
        video_path = os.path.join(FOLDER_PATH, row['file']) # get the video path
        start = row['start']
        stop = row['end']
        base, extension = os.path.splitext(row['file'])  # Separate filename base and extension

        # Generate new filename with underscore and incrementing number
        new_filename = f"{base}_{file_count[row['file']] + 1}{extension}" # assign a new video name
        output_path = os.path.join(OUTPUT_PATH, new_filename) # new video path

        # Increment processing count for the current file
        file_count[row['file']] += 1

        # intiate crop
        crop(video_path, start, stop, output_path)

        
    
    return 'All video files have been cropped'

# %% [markdown]
# Only Microsoft-ASL video files downloaded from YouTube requires video cropping. The WL-ASL files have frames that show the signed action, so they will not be part of the function call to crop the video.

# %%
# crop the videos in a single for-loop for all 3 folders and all actions

for vid in first_three:
    get_crop_video(vid, 'train_data', train_df)
    get_crop_video(vid, 'test_data', test_df)
    get_crop_video(vid, 'val_data', val_df)
# Out:
# INFO - Video has been cropped and saved. ../videos/train_data\please\Examples of Baby Sign Language.mp4
# INFO - Video has been cropped and saved. ../videos/train_data\please\Examples of Baby Sign Language.mp4
# INFO - Video has been cropped and saved. ../videos/train_data\please\Making Conversation Vocabulary  ASL - American Sign Language.mp4
# INFO - Video has been cropped and saved. ../videos/train_data\please\Basic Sign Language for Caregivers of the DeafHard of Hearing.mp4
# ERROR - Error opening video file: File not Available ../videos/train_data\please\ASL Vocabulary (Spring 2018).mp4
# ERROR - Error opening video file: File not Available ../videos/train_data\please\Permission.mp4
# INFO - Video has been cropped and saved. ../videos/train_data\please\Basic Sign Language for Caregivers of the DeafHard of Hearing.mp4
# INFO - Video has been cropped and saved. ../videos/train_data\please\ASL Level 1 Unit 1 Vocabulary.mp4
# ERROR - Error opening video file: File not Available ../videos/train_data\please\Baby Sign Language Please.mp4
# INFO - Video has been cropped and saved. ../videos/train_data\please\Unit 2 Vocabularymp4.mp4
# INFO - Video has been cropped and saved. ../videos/train_data\please\Basic Sign Language for Caregivers (mealtime).mp4
# ERROR - Error opening video file: File not Available ../videos/train_data\please\CCHS ASL Unit 1.mp4
# INFO - Video has been cropped and saved. ../videos/train_data\please\ASL Class 02-08-10.mp4
# ERROR - Error opening video file: File not Available ../videos/train_data\please\Unit 1(1).mp4
# ERROR - Error opening video file: File not Available ../videos/train_data\please\Unit 1 Vocabulary(2).mp4
# ERROR - Error opening video file: File not Available ../videos/train_data\please\SignSchool Please.mp4
# ERROR - Error opening video file: File not Available ../videos/train_data\please\Introduction to American Sign Language Questions and Small Talk.mp4
# INFO - Video has been cropped and saved. ../videos/train_data\please\Please.mp4
# INFO - Video has been cropped and saved. ../videos/train_data\please\Unit 02 Vocabulary.mp4
# ERROR - Error opening video file: File not Available ../videos/train_data\please\American Sign Language Learning the basics.mp4
# INFO - Video has been cropped and saved. ../videos/train_data\please\Please - Asl.mp4
# ERROR - Error opening video file: File not Available ../videos/train_data\please\Unit 1 Survival Signs.mp4
# INFO - Video has been cropped and saved. ../videos/train_data\please\please - ASL sign for please.mp4
# INFO - Video has been cropped and saved. ../videos/train_data\please\please - ASL sign for please.mp4
# INFO - Video has been cropped and saved. ../videos/train_data\please\First 100 Social Function.mp4
# INFO - Video has been cropped and saved. ../videos/train_data\please\Basic Sign Language for Caregivers (mealtime).mp4
# ERROR - Error opening video file: File not Available ../videos/train_data\please\Permission.mp4
# ERROR - Error opening video file: File not Available ../videos/train_data\please\ASL Vocabulary please.mp4
# INFO - Video has been cropped and saved. ../videos/train_data\please\ASL Unit One Vocabulary.mp4
# INFO - Video has been cropped and saved. ../videos/train_data\please\Unit 2 Vocabularymp4.mp4
# ERROR - Error opening video file: File not Available ../videos/train_data\please\Unit 1 Vocabulary(2).mp4
# INFO - Video has been cropped and saved. ../videos/train_data\please\How to sign Please - ASL Vocabulary Series.mp4
# ERROR - Error opening video file: File not Available ../videos/train_data\please\SN Unit 1 Video Vocab Review.mp4
# INFO - Video has been cropped and saved. ../videos/train_data\please\please - ASL sign for please.mp4
# INFO - Video has been cropped and saved. ../videos/train_data\please\Making Conversation Vocabulary  ASL - American Sign Language.mp4
# INFO - Video has been cropped and saved. ../videos/train_data\please\Beginner Vocabulary.mp4
# ERROR - Error opening video file: File not Available ../videos/train_data\please\Unit 1 Vocabulary(2).mp4
# ERROR - Error opening video file: File not Available ../videos/train_data\please\ASL Vocabulary please.mp4
# ERROR - Error opening video file: File not Available ../videos/train_data\please\Unit 1 Vocabulary(2).mp4
# INFO - Video has been cropped and saved. ../videos/test_data\please\Lesson 2 Vocabulary - A Basic Course (ABC) in ASL.mp4
# INFO - Video has been cropped and saved. ../videos/test_data\please\Unit 1 Vocabulary.mp4
# INFO - Video has been cropped and saved. ../videos/test_data\please\Unit 2 Vocabulary Words.mp4
# ERROR - Error opening video file: File not Available ../videos/test_data\please\ASL1 Class 4 New SIGNS plus Partner Practice QA and p29 Dialogue.mp4
# ERROR - Error opening video file: File not Available ../videos/test_data\please\PLEASE(1).mp4
# ERROR - Error opening video file: File not Available ../videos/test_data\please\PLEASE.mp4
# ERROR - Error opening video file: File not Available ../videos/test_data\please\ASL Top ASL Signs for Servers.mp4
# ERROR - Error opening video file: File not Available ../videos/test_data\please\ASL Top ASL Signs for Servers.mp4
# ERROR - Error opening video file: File not Available ../videos/val_data\please\The First 100 Signs You Need to Know.mp4
# ERROR - Error opening video file: File not Available ../videos/val_data\please\ASL Unit 1 Vocab with Captions.mp4
# ERROR - Error opening video file: File not Available ../videos/val_data\please\Aug to Oct Voc Captions.mp4
# INFO - Video has been cropped and saved. ../videos/val_data\please\ASL1Chapter2 Vocab.mp4
# ERROR - Error opening video file: File not Available ../videos/val_data\please\School Signs.mp4
# ERROR - Error opening video file: File not Available ../videos/val_data\please\The First 100 Signs You Need to Know.mp4
# INFO - Video has been cropped and saved. ../videos/val_data\please\ASL - ASL Necessities for ASL 1.mp4
# ERROR - Error opening video file: File not Available ../videos/val_data\please\ASL 1 - Unit 1 Vocabulary Word List.mp4
# ERROR - Error opening video file: File not Available ../videos/val_data\please\ASL 1 - Unit 1 Vocabulary Word List.mp4
# INFO - Video has been cropped and saved. ../videos/val_data\please\ASL I - Unit 1 Vocabulary.mp4
# INFO - Video has been cropped and saved. ../videos/train_data\sorry\sorry - ASL sign for sorry.mp4
# ERROR - Error opening video file: File not Available ../videos/train_data\sorry\SORRY(1).mp4
# INFO - Video has been cropped and saved. ../videos/train_data\sorry\ASL 1 Unit 3 Vocabulary.mp4
# INFO - Video has been cropped and saved. ../videos/train_data\sorry\Sorry - Asl.mp4
# INFO - Video has been cropped and saved. ../videos/train_data\sorry\Basic Sign Language for Caregivers of the DeafHard of Hearing.mp4
# ERROR - Error opening video file: File not Available ../videos/train_data\sorry\CCHS ASL Unit 5.mp4
# ERROR - Error opening video file: File not Available ../videos/train_data\sorry\CCHS ASL Unit 1.mp4
# ERROR - Error opening video file: File not Available ../videos/train_data\sorry\Baby Sign Language Sorry.mp4
# ERROR - Error opening video file: File not Available ../videos/train_data\sorry\Unit 1 Survival Signs.mp4
# ERROR - Error opening video file: File not Available ../videos/train_data\sorry\Unit 1 Survival Signs.mp4
# INFO - Video has been cropped and saved. ../videos/train_data\sorry\sorry - ASL sign for sorry.mp4
# INFO - Video has been cropped and saved. ../videos/train_data\sorry\Beginner Vocabulary.mp4
# ERROR - Error opening video file: File not Available ../videos/train_data\sorry\Barista ASL Vocabulary.mp4
# ERROR - Error opening video file: File not Available ../videos/train_data\sorry\SN Unit 1 Video Vocab Review.mp4
# ERROR - Error opening video file: File not Available ../videos/train_data\sorry\Introduction to American Sign Language Questions and Small Talk.mp4
# INFO - Video has been cropped and saved. ../videos/train_data\sorry\sorry - ASL sign for sorry.mp4
# ERROR - Error opening video file: File not Available ../videos/train_data\sorry\ASL Vocabulary sorry.mp4
# ERROR - Error opening video file: File not Available ../videos/train_data\sorry\ASL Vocabulary sorry.mp4
# INFO - Video has been cropped and saved. ../videos/train_data\sorry\ASL Level 1 Unit 1 Vocabulary.mp4
# INFO - Video has been cropped and saved. ../videos/train_data\sorry\UNIT 10 VOCABULARY.mp4
# INFO - Video has been cropped and saved. ../videos/train_data\sorry\Sorry.mp4
# ERROR - Error opening video file: File not Available ../videos/train_data\sorry\SignSchool sorry.mp4
# INFO - Video has been cropped and saved. ../videos/train_data\sorry\Unit 03 Vocabulary.mp4
# ERROR - Error opening video file: File not Available ../videos/train_data\sorry\Permission.mp4
# ERROR - Error opening video file: File not Available ../videos/train_data\sorry\Permission.mp4
# ERROR - Error opening video file: File not Available ../videos/test_data\sorry\SORRY.mp4
# INFO - Video has been cropped and saved. ../videos/test_data\sorry\Lesson 4 Vocabulary - A Basic Course (ABC) in ASL.mp4
# ERROR - Error opening video file: File not Available ../videos/test_data\sorry\ASL Top ASL Signs for Servers.mp4
# ERROR - Error opening video file: File not Available ../videos/test_data\sorry\ASL Top ASL Signs for Servers.mp4
# ERROR - Error opening video file: File not Available ../videos/test_data\sorry\Unit 4 Vocabulary (part 2)  ASL  American Sign Language.mp4
# INFO - Video has been cropped and saved. ../videos/val_data\sorry\ASL - ASL Necessities for ASL 1.mp4
# ERROR - Error opening video file: File not Available ../videos/val_data\sorry\ASL 1 - Unit 1 Vocabulary Word List.mp4
# INFO - Video has been cropped and saved. ../videos/val_data\sorry\Sorry in Sign Language ASL Dictionary for kids.mp4
# ERROR - Error opening video file: File not Available ../videos/val_data\sorry\The First 100 Signs You Need to Know.mp4
# ERROR - Error opening video file: File not Available ../videos/val_data\sorry\50 Different Feelings  Emotions in ASL.mp4
# ERROR - Error opening video file: File not Available ../videos/val_data\sorry\Aug to Oct Voc Captions.mp4
# INFO - Video has been cropped and saved. ../videos/val_data\sorry\ASL1Chapter2 Vocab.mp4
# ERROR - Error opening video file: File not Available ../videos/val_data\sorry\50 Different Feelings  Emotions in ASL.mp4
# INFO - Video has been cropped and saved. ../videos/val_data\sorry\Mr Miseners ASL lesson 4 review.mp4
# ERROR - Error opening video file: File not Available ../videos/val_data\sorry\The First 100 Signs You Need to Know.mp4
# INFO - Video has been cropped and saved. ../videos/val_data\sorry\ASL I - Unit 1 Vocabulary.mp4
# ERROR - Error opening video file: File not Available ../videos/val_data\sorry\Breakup Vocabulary.mp4
# ERROR - Error opening video file: File not Available ../videos/val_data\sorry\Breakup Vocabulary.mp4
# ERROR - Error opening video file: File not Available ../videos/val_data\sorry\SORRY(2).mp4
# INFO - Video has been cropped and saved. ../videos/val_data\sorry\Unit 3.mp4
# INFO - Video has been cropped and saved. ../videos/val_data\sorry\ASL1Chapter2 Vocab.mp4
# INFO - Video has been cropped and saved. ../videos/val_data\sorry\Unit 11 Signing Naturally ASL II.mp4
# INFO - Video has been cropped and saved. ../videos/val_data\sorry\Unit 3.mp4
# INFO - Video has been cropped and saved. ../videos/val_data\sorry\ASL1Chapter2 Vocab.mp4
# ERROR - Error opening video file: File not Available ../videos/train_data\hello\American Sign Language Learning the basics.mp4
# ERROR - Error opening video file: File not Available ../videos/train_data\hello\Unit 1 Vocabulary(2).mp4
# ERROR - Error opening video file: File not Available ../videos/train_data\hello\Unit 1 Vocabulary(2).mp4
# ERROR - Error opening video file: File not Available ../videos/train_data\hello\ASL Vocabulary hello.mp4
# ERROR - Error opening video file: File not Available ../videos/train_data\hello\ASL Vocabulary hello.mp4
# INFO - Video has been cropped and saved. ../videos/train_data\hello\ASL Numbers 1 10   Arkansas School for the Deaf.mp4
# ERROR - Error opening video file: File not Available ../videos/train_data\hello\American Sign Language Learning the basics.mp4
# INFO - Video has been cropped and saved. ../videos/train_data\hello\Signing Naturally Unit 1 Vocabulary.mp4
# ERROR - Error opening video file: File not Available ../videos/train_data\hello\Unit 1 Vocabulary(3).mp4
# INFO - Video has been cropped and saved. ../videos/train_data\hello\hello.mp4
# INFO - Video has been cropped and saved. ../videos/train_data\hello\ASL Vocabulary (Spring 2018).mp4
# ERROR - Error opening video file: File not Available ../videos/train_data\hello\Introductions.mp4
# ERROR - Error opening video file: File not Available ../videos/train_data\hello\Introductions.mp4
# INFO - Video has been cropped and saved. ../videos/train_data\hello\deaffriendly ASL Vocabulary - Hotel.mp4
# INFO - Video has been cropped and saved. ../videos/train_data\hello\ASL UNIT 1 VOCAB  signing naturally.mp4
# ERROR - Error opening video file: File not Available ../videos/train_data\hello\Unit 1 Vocabulary(1).mp4
# ERROR - Error opening video file: File not Available ../videos/train_data\hello\Barista ASL Vocabulary.mp4
# INFO - Video has been cropped and saved. ../videos/train_data\hello\Hello.mp4
# INFO - Video has been cropped and saved. ../videos/train_data\hello\How to sign Hello.mp4
# INFO - Video has been cropped and saved. ../videos/train_data\hello\How are you.mp4
# INFO - Video has been cropped and saved. ../videos/train_data\hello\Unit 01 Vocabulary.mp4
# INFO - Video has been cropped and saved. ../videos/train_data\hello\ASL Unit One Vocabulary.mp4
# INFO - Video has been cropped and saved. ../videos/train_data\hello\Greetings.mp4
# ERROR - Error opening video file: File not Available ../videos/train_data\hello\Unit 1 Vocabulary(2).mp4
# ERROR - Error opening video file: File not Available ../videos/train_data\hello\SN Unit 1 Video Vocab Review.mp4
# INFO - Video has been cropped and saved. ../videos/train_data\hello\Unit 1 Vocabulary  ASL Level 1 - American Sign Language.mp4
# INFO - Video has been cropped and saved. ../videos/train_data\hello\Hello - Asl.mp4
# ERROR - Error opening video file: File not Available ../videos/train_data\hello\Greeting B.mp4
# ERROR - Error opening video file: File not Available ../videos/train_data\hello\Hello(1).mp4
# ERROR - Error opening video file: File not Available ../videos/train_data\hello\HELLO(1).mp4
# INFO - Video has been cropped and saved. ../videos/test_data\hello\ASL1 Class 48 New SIGNS.mp4
# ERROR - Error opening video file: File not Available ../videos/test_data\hello\ASL Top ASL Signs for Servers.mp4
# INFO - Video has been cropped and saved. ../videos/test_data\hello\ASL3 Class 23 Vocabulary.mp4
# INFO - Video has been cropped and saved. ../videos/test_data\hello\ASL1 Class 29 New SIGNS.mp4
# ERROR - Error opening video file: File not Available ../videos/test_data\hello\ASL Top ASL Signs for Servers.mp4
# INFO - Video has been cropped and saved. ../videos/test_data\hello\ASL2 Class 54 SIGNS.mp4
# INFO - Video has been cropped and saved. ../videos/test_data\hello\ASL2 Class 53 SIGNS.mp4
# ERROR - Error opening video file: File not Available ../videos/test_data\hello\Unit 17 - Weather ASL (American Sign Language) CC.mp4
# INFO - Video has been cropped and saved. ../videos/test_data\hello\Unit 1 Vocabulary.mp4
# ERROR - Error opening video file: File not Available ../videos/test_data\hello\HELLO.mp4
# INFO - Video has been cropped and saved. ../videos/test_data\hello\Lesson 1 Vocabulary - A Basic Course (ABC) in ASL.mp4
# INFO - Video has been cropped and saved. ../videos/test_data\hello\ASL1 Class 15 New SIGNS.mp4
# ERROR - Error opening video file: File not Available ../videos/test_data\hello\ASL Countries - American Sign Language turn on captions.mp4
# ERROR - Error opening video file: File not Available ../videos/test_data\hello\ASL Unit 5 Vocabulary - Clothing Part 1 and 2 Turn on CC.mp4
# INFO - Video has been cropped and saved. ../videos/test_data\hello\ASL2 Class 52 SIGNS.mp4
# ERROR - Error opening video file: File not Available ../videos/test_data\hello\SignSchool Hello.mp4
# ERROR - Error opening video file: File not Available ../videos/test_data\hello\HELLO(2).mp4
# ERROR - Error opening video file: File not Available ../videos/test_data\hello\ASL1 Class 4 New SIGNS plus Partner Practice QA and p29 Dialogue.mp4
# INFO - Video has been cropped and saved. ../videos/test_data\hello\ASL1 Class 5 New SIGNS.mp4
# ERROR - Error opening video file: File not Available ../videos/test_data\hello\ASL2 Class 51 SIGNS.mp4
# INFO - Video has been cropped and saved. ../videos/val_data\hello\Unit 1.mp4
# INFO - Video has been cropped and saved. ../videos/val_data\hello\Mr Miseners ASL lesson 1 vocab review.mp4
# ERROR - Error opening video file: File not Available ../videos/val_data\hello\Social Work Voc.mp4
# INFO - Video has been cropped and saved. ../videos/val_data\hello\ASL I - Unit 1 Vocabulary.mp4
# ERROR - Error opening video file: File not Available ../videos/val_data\hello\Greetings  Answers in American Sign Language.mp4
# ERROR - Error opening video file: File not Available ../videos/val_data\hello\HELLO(3).mp4
# INFO - Video has been cropped and saved. ../videos/val_data\hello\ASL1Chapter1 Vocab.mp4
# ERROR - Error opening video file: File not Available ../videos/val_data\hello\The First 100 Signs You Need to Know.mp4
# ERROR - Error opening video file: File not Available ../videos/val_data\hello\The First 100 Signs You Need to Know.mp4
# INFO - Video has been cropped and saved. ../videos/val_data\hello\ASL1Chapter1 Vocab.mp4
# ERROR - Error opening video file: File not Available ../videos/val_data\hello\ASL 1 - Unit 1 Vocabulary Word List.mp4
# ERROR - Error opening video file: File not Available ../videos/val_data\hello\ASL 1 - Unit 1 Vocabulary Word List.mp4
# ERROR - Error opening video file: File not Available ../videos/val_data\hello\ASL Unit 1 Vocab with Captions.mp4
# ERROR - Error opening video file: File not Available ../videos/val_data\hello\Aug to Oct Voc Captions.mp4

# %% [markdown]
# At the moment, WL-ASl dataset is separate from MS-ASL dataset, we will combing the video files from the WL-ASl into the train data folder which is from MS-ASl so that when we extract the keypoints from the video files, it can be done together.

# %%
# Using a for-loop to move the videos from the WL-ASL dataset to another sub-folder titled 'cropped_videos' to combine training data

# recalling the actions we will be using
first_three = ['please', 'sorry', 'hello']

# the folder directories of WL-ASL and the destination folder
WLASL_PATH = '../videos/wlasl_data/' # main folder path for WL-ASL
DST_PATH = '../videos/train_data/'   # destination path for train data

# initiate for loop in the source firectory
for folder in os.listdir(WLASL_PATH):

    # only access the folder names in the list of words
    if folder in first_three: 
        # print(folder) # debug
        SOURCE_FOLDER = os.path.join(WLASL_PATH, folder ) # updated file path with folder names
        DST_FOLDER = os.path.join(DST_PATH, folder , 'cropped_videos') # destination path of where it should be copied to

        # nested loop for each video file inside each word folder
        for video in os.listdir(SOURCE_FOLDER):
            # print(video) # debug
            try:
                # make a copy of the video file to the newly made folder
                SOURCE_PATH = os.path.join(SOURCE_FOLDER, video ) # source file location

                # print(SOURCE_PATH) # debug
                # print(DST_FOLDER) # debug
                
                shutil.copy(SOURCE_PATH, DST_FOLDER) # creates a copy of the file

            except Exception as e:
                continue

# %% [markdown]
# ## 2.3 Resize and adjust FPS
#
#
# As the all videos, including WL-ASL, have different fps and are different dimensions, we will keep it standardized and adjust the frames-per-second (fps) to `30` and with an aspect ratio of `512 x 512 pixels`.

# %%
# define a function to resize a single video to the pre-determined fps and image size

def resize_video_file(input_video_path, output_video_path, fps=30, target_size=(512, 512)):
    '''
    Resizes a video to a specific size and frame rate.

    Args:
    input_video_path: Path to the input video file.
    output_video_path: Path to save the resized video file.
    fps: Target frames per second for the output video (default: 30).
    target_size: Target width and height for the resized video frames (default: (512, 512)).
    '''

    # Open the video file for reading
    cap = cv2.VideoCapture(input_video_path)

    # Check if the clip cannot be opened
    if not cap.isOpened():
        #print('Error: Cannot open video file ', input_video_path)
        logging.error('Error: Cannot open video file. %s', input_video_path)
        return

    # define the codec to be used for writing the file
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')

    # write output video file with the above conditions
    out = cv2.VideoWriter(output_video_path, fourcc, fps, target_size)

    # initialize the start counter for number of processed frames
    processed_frames = 0

    # while the clip is read
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        
        # resize the clip to the target size
        resized_frame = cv2.resize(frame, target_size)

        # write the resized frame to the output video file
        out.write(resized_frame)

        # break logic once 60 frames have been read
        if processed_frames == 60:
            break
        # increment the counter once each frame is read
        processed_frames += 1

    # release video capture object
    cap.release()
    # release video writer object
    out.release()

    #print(f'Number of frames processed: {processed_frames}') # debug
    #print('Video processing complete.') # debug
    logging.info('Number of frames processed: %s', processed_frames) # write logging file
    logging.info('Video processing complete.') # write logging file
    



# create a function to resize all files within the same folder (action)
def resize_class_videos(label:str, save_folder:str):
    '''
    Resizes all videos in a specific label's 'cropped_videos' directory.

    Args:
    label: The label of the video category to process.
    save_folder: The folder of the dataset - train_data, test_data, val_data
    '''

    # common path 
    GENERAL_PATH = '../videos/'

    # the folder of source video files
    LABEL_PATH = os.path.join(GENERAL_PATH, save_folder + '/' + label + '/cropped_videos/')

    # the destination folder of where the resized files will be saved
    OUTPUT_DIR = os.path.join('../videos/', save_folder + '/output/'  + label + '/')

    # create a destination folder and check if it exists
    os.makedirs(OUTPUT_DIR, exist_ok=True)  

    # intialize counter for file naming
    count = 1

    # loop each source folder
    for vid in os.listdir(LABEL_PATH):

        # video file path
        VIDEO_PATH = os.path.join(LABEL_PATH, vid)
        # print('Resizing: ', vid) # debug
        logging.info('Video file resized: %s', vid) # write into logging file

        # Ensure the output filename does not conflict and has the correct extension, and rename the resized video file
        OUT_PATH = os.path.join(OUTPUT_DIR, f'{label}_{count}.mp4')

        # call on the resize_video_file function defined above
        resize_video_file(VIDEO_PATH, OUT_PATH)
        count += 1 # increment counter

    return 'All video files have been resized'

# %%
# Resize the all video files with one loop to 30 fps and with an aspect ratio of 512 x 512 pixels

for vid in first_three:
    resize_class_videos(vid, 'train_data')
    resize_class_videos(vid, 'test_data')
    resize_class_videos(vid, 'val_data')
# Out:
# INFO - Video file resized: 43217_.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: 43218_.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: 43219_.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: 43220_.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: 43222_.mp4
# INFO - Number of frames processed: 44
# INFO - Video processing complete.
# INFO - Video file resized: 43226_.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: 69434_.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: ASL Class 02-08-10_1.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: ASL Level 1 Unit 1 Vocabulary_1.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: ASL Unit One Vocabulary_1.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: Basic Sign Language for Caregivers (mealtime)_1.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: Basic Sign Language for Caregivers (mealtime)_2.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: Basic Sign Language for Caregivers of the DeafHard of Hearing_1.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: Basic Sign Language for Caregivers of the DeafHard of Hearing_2.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: Beginner Vocabulary_1.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: Examples of Baby Sign Language_1.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: Examples of Baby Sign Language_2.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: First 100 Social Function_1.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: How to sign Please - ASL Vocabulary Series_1.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: Making Conversation Vocabulary  ASL - American Sign Language_1.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: Making Conversation Vocabulary  ASL - American Sign Language_2.mp4
# INFO - Number of frames processed: 49
# INFO - Video processing complete.
# INFO - Video file resized: please - ASL sign for please_1.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: please - ASL sign for please_2.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: please - ASL sign for please_3.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: Please - Asl_1.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: Please_1.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: Unit 02 Vocabulary_1.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: Unit 2 Vocabularymp4_1.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: Unit 2 Vocabularymp4_2.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: Lesson 2 Vocabulary - A Basic Course (ABC) in ASL_1.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: Unit 1 Vocabulary_1.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: Unit 2 Vocabulary Words_1.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: ASL - ASL Necessities for ASL 1_1.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: ASL I - Unit 1 Vocabulary_1.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: ASL1Chapter2 Vocab_1.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: 53365_.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: 53366_.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: 53367_.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: 53370_.mp4
# INFO - Number of frames processed: 42
# INFO - Video processing complete.
# INFO - Video file resized: 53371_.mp4
# INFO - Number of frames processed: 50
# INFO - Video processing complete.
# INFO - Video file resized: 53375_.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: 66536_.mp4
# INFO - Number of frames processed: 59
# INFO - Video processing complete.
# INFO - Video file resized: ASL 1 Unit 3 Vocabulary_1.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: ASL Level 1 Unit 1 Vocabulary_1.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: Basic Sign Language for Caregivers of the DeafHard of Hearing_1.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: Beginner Vocabulary_1.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: sorry - ASL sign for sorry_1.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: sorry - ASL sign for sorry_2.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: sorry - ASL sign for sorry_3.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: Sorry - Asl_1.mp4
# INFO - Number of frames processed: 55
# INFO - Video processing complete.
# INFO - Video file resized: Sorry_1.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: Unit 03 Vocabulary_1.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: UNIT 10 VOCABULARY_1.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: Lesson 4 Vocabulary - A Basic Course (ABC) in ASL_1.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: ASL - ASL Necessities for ASL 1_1.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: ASL I - Unit 1 Vocabulary_1.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: ASL1Chapter2 Vocab_1.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: ASL1Chapter2 Vocab_2.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: ASL1Chapter2 Vocab_3.mp4
# INFO - Number of frames processed: 40
# INFO - Video processing complete.
# INFO - Video file resized: Mr Miseners ASL lesson 4 review_1.mp4
# INFO - Number of frames processed: 53
# INFO - Video processing complete.
# INFO - Video file resized: Sorry in Sign Language ASL Dictionary for kids_1.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: Unit 11 Signing Naturally ASL II_1.mp4
# INFO - Number of frames processed: 50
# INFO - Video processing complete.
# INFO - Video file resized: Unit 3_1.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: Unit 3_2.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: 27172_.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: 27173_.mp4
# INFO - Number of frames processed: 58
# INFO - Video processing complete.
# INFO - Video file resized: 27177_.mp4
# INFO - Number of frames processed: 31
# INFO - Video processing complete.
# INFO - Video file resized: 27184_.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: ASL Numbers 1 10   Arkansas School for the Deaf_1.mp4
# INFO - Number of frames processed: 34
# INFO - Video processing complete.
# INFO - Video file resized: ASL UNIT 1 VOCAB  signing naturally_1.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: ASL Unit One Vocabulary_1.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: ASL Vocabulary (Spring 2018)_1.mp4
# INFO - Number of frames processed: 52
# INFO - Video processing complete.
# INFO - Video file resized: deaffriendly ASL Vocabulary - Hotel_1.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: Greetings_1.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: Hello - Asl_1.mp4
# INFO - Number of frames processed: 45
# INFO - Video processing complete.
# INFO - Video file resized: hello_1.mp4
# INFO - Number of frames processed: 52
# INFO - Video processing complete.
# INFO - Video file resized: How are you_1.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: How to sign Hello_1.mp4
# INFO - Number of frames processed: 49
# INFO - Video processing complete.
# INFO - Video file resized: Signing Naturally Unit 1 Vocabulary_1.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: Unit 01 Vocabulary_1.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: Unit 1 Vocabulary  ASL Level 1 - American Sign Language_1.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: ASL1 Class 15 New SIGNS_1.mp4
# INFO - Number of frames processed: 35
# INFO - Video processing complete.
# INFO - Video file resized: ASL1 Class 29 New SIGNS_1.mp4
# INFO - Number of frames processed: 30
# INFO - Video processing complete.
# INFO - Video file resized: ASL1 Class 48 New SIGNS_1.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: ASL1 Class 5 New SIGNS_1.mp4
# INFO - Number of frames processed: 40
# INFO - Video processing complete.
# INFO - Video file resized: ASL2 Class 52 SIGNS_1.mp4
# INFO - Number of frames processed: 34
# INFO - Video processing complete.
# INFO - Video file resized: ASL2 Class 53 SIGNS_1.mp4
# INFO - Number of frames processed: 30
# INFO - Video processing complete.
# INFO - Video file resized: ASL2 Class 54 SIGNS_1.mp4
# INFO - Number of frames processed: 39
# INFO - Video processing complete.
# INFO - Video file resized: ASL3 Class 23 Vocabulary_1.mp4
# INFO - Number of frames processed: 32
# INFO - Video processing complete.
# INFO - Video file resized: Lesson 1 Vocabulary - A Basic Course (ABC) in ASL_1.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: Unit 1 Vocabulary_1.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: ASL I - Unit 1 Vocabulary_1.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: ASL1Chapter1 Vocab_1.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: ASL1Chapter1 Vocab_2.mp4
# INFO - Number of frames processed: 50
# INFO - Video processing complete.
# INFO - Video file resized: Mr Miseners ASL lesson 1 vocab review_1.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.
# INFO - Video file resized: Unit 1_1.mp4
# INFO - Number of frames processed: 60
# INFO - Video processing complete.

# %% [markdown]
# We will obtain the number of video files we have after cropping and resizing the video clips

# %%
# List of folders to count files in
folder_list = ['train_data', 'test_data', 'val_data']

# Function to count files in a folder
def count_files(folder_path):
    file_count = defaultdict(int)
    for file_name in os.listdir(folder_path):
        if os.path.isfile(os.path.join(folder_path, file_name)):
            file_count[''] += 1  # Counting files in the root folder
    return file_count

# Base path where the folders are located
FILE_PATH = '../videos/'

# Iterate through each action and folder to count files
for action in first_three:
    for folder in folder_list:
        # Construct the full path to the folder
        FOLDER_PATH = os.path.join(FILE_PATH, folder, action, 'cropped_videos')
        
        # Count the files in the folder
        file_count = count_files(FOLDER_PATH)
        
        # Print the count of files in the folder
        print(f'Files in {folder} {action}: {file_count[""]}')
    print('-' * 30)
# Out:
# Files in train_data please: 29
# Files in test_data please: 3
# Files in val_data please: 3
# ------------------------------
# Files in train_data sorry: 18
# Files in test_data sorry: 1
# Files in val_data sorry: 10
# ------------------------------
# Files in train_data hello: 17
# Files in test_data hello: 10
# Files in val_data hello: 5
# ------------------------------

# %% [markdown]
# ---
# ## 2.4 Data Augmentation
#
# As the amount of video files are not sufficient for a robust model, we will augment the video files through:
#
# - flipping horizontally
# - reducing the brightness
# - adjusting the contrast
# - shearing left
# - shearing right
# - gaussian blur

# %% [markdown]
# ### 2.4.1 Flip the video horizontally
#
# Horizontally flipping the videos increases the diversity of the training data by effectively doubling the amount of data available without changing the semantics of the video. It also encourages the model to learn features from another viewpoint, like in signed actions, flipping the video essentially changes the signing hand. This would help improve its generalization ability.

# %%
# Function to flip a video horizontally
def flip_video_horizontally(input_video_path, output_video_path):
    '''
    Flip the video file horizontally

    Args:
    input_video_path: path of the video file
    output_video_path: path of the destination folder to write to
    '''
    # Open the input video file
    cap = cv2.VideoCapture(input_video_path)

    # Define the codec and create VideoWriter object
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_video_path, fourcc, cap.get(cv2.CAP_PROP_FPS),
                          (int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)), int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))))
    
    # Loop through each frame in the video
    while True:
        ret, frame = cap.read() # read the frame from the video
        if not ret: # if cannot read frame, break loop
            break

        # Flip the frame horizontally
        flipped_frame = cv2.flip(frame, 1)
        # write the flipped frame to the output video
        out.write(flipped_frame)

    # Release video capture object
    cap.release()
    # release video write object
    out.release()
    # print("Video flipped and saved to", output_video_path) # debug
    

# function to augment all video clips within the folder and action
def augment_by_flip(label:str, save_folder:str):
    '''
    Flip videos horizontally in a given folder by passing
    the following arguments

    Args:
    label: The label of the video category to process.
    save_folder: the folder name: 'train_data', 'test_data', 'val_data'
    '''
    # General path of video files
    GENERAL_PATH = '../videos/'
    
    # Construct  the path to the folder containing the labeled videos
    LABEL_PATH = os.path.join(GENERAL_PATH, save_folder + '/output/' + label + '/')

    # Define the output directory where flipped videos will be saved
    OUTPUT_DIR = os.path.join('../videos/', save_folder + '/output/'  + label + '/videos_to_annotate/')

    # create a destination folder and check if it exists
    os.makedirs(OUTPUT_DIR, exist_ok=True)  

    # intialize counter for file naming
    count = 1

    # get a list of video files in the labelled folder
    video_files = os.listdir(LABEL_PATH)
    
    # only read video files and not the created nested folder
    video_files = [f for f in video_files if f.endswith(('.mp4'))]
    
    # loop through each video in the video folder
    for vid in video_files:
        
        # construct the full path to the input video
        VIDEO_PATH = os.path.join(LABEL_PATH, vid)
        # print('Flipping: ', vid) # debug
        logging.info('Video augmented by flipping: %s', vid) # write to logging file
        

        # Ensure the output filename does not conflict and has the correct extension
        OUT_PATH = os.path.join(OUTPUT_DIR, f'{label}_flipped_{count}.mp4')

        # call the function to flip the video horizontally
        flip_video_horizontally(VIDEO_PATH, OUT_PATH)

        count += 1 # increment the count
       
    return 'All video files have been augmented by flipping horizontally'

# %% [markdown]
# ### 2.4.2 Decrease Video Brightness
#
# This simulates scenarios with varying lighting conditions, making the model robust to changes in illumination, it also prevents the model from overfitting to a specific lighting conditions present in the training data. Most of the videos in the dataset are in controlled environment with adequate lighting.

# %%
# Function to decrease the brightness of the video
def make_video_darker(input_video_path, output_video_path, brightness_reduction=30):

    '''
    Decrease the brightness of the video

    Args:
    input_video_path: path of the video file
    output_video_path: path of the destination folder to write to
    brightness_reduction: amount to decrease brightness, default: 30
    '''

     # Open the input video file
    cap = cv2.VideoCapture(input_video_path)

    # Define the codec and create VideoWriter object
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_video_path, fourcc, cap.get(cv2.CAP_PROP_FPS),
                          (int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)), int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))))
    
    # Loop through each frame in the video
    while True:
        ret, frame = cap.read() # read the frame from the video
        if not ret: # if cannot read frame, break loop
            break

        # Convert to HSV to adjust brightness
        hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
        h, s, v = cv2.split(hsv) # hue, saturation, value

        # reduce brightness
        v = v.astype(np.float32)
        v = v * (1 - brightness_reduction / 100.0)  # reduce brightness
        v = np.clip(v, 0, 255).astype(np.uint8) # ensure pixel values are within 0-255

        # merge the HSV components back into one image
        final_hsv = cv2.merge((h, s, v))
        darker_frame = cv2.cvtColor(final_hsv, cv2.COLOR_HSV2BGR)
        out.write(darker_frame) # write the reduced brightness frame to the output video

    # Release video capture object
    cap.release()
    # release video write object
    out.release()
    # print("Video darkened and saved to", output_video_path) # debug


# define a function to decrease brightness by action and folder
def augment_by_darken(label:str, save_folder:str):
    '''
    Reduce brightness in a given folder by passing
    the following arguments

    Args:
    label: The label of the video category to process.
    save_folder: the folder name: 'train_data', 'test_data', 'val_data'
    '''

    # General path of video files
    GENERAL_PATH = '../videos/'

    # Construct  the path to the folder containing the labeled videos
    LABEL_PATH = os.path.join(GENERAL_PATH, save_folder + '/output/' + label + '/')

    # Define the output directory where videos will be saved
    OUTPUT_DIR = os.path.join('../videos/', save_folder + '/output/'  + label + '/videos_to_annotate/')

    # create a destination folder and check if it exists
    os.makedirs(OUTPUT_DIR, exist_ok=True)  

    # intialize counter for file naming
    count = 1

    # only read video files and not the created nested folder
    video_files = [f for f in os.listdir(LABEL_PATH) if f.endswith('.mp4')]
    
    # loop through each video in the video folder
    for vid in video_files:

        # construct the full path to the input video
        VIDEO_PATH = os.path.join(LABEL_PATH, vid)
        #print('Darkening: ', vid) # debug
        logging.info('Video augmented by reducing brightness: %s', vid) # write to logging file

        # Ensure the output filename does not conflict and has the correct extension
        OUT_PATH = os.path.join(OUTPUT_DIR, f'{label}_darkened_{count}.mp4')

        # call the function to decrease the brightness of the video clip
        make_video_darker(VIDEO_PATH, OUT_PATH)
        
        count += 1 # increment the count
        

    return f'All video files have been augmented by darkening the video'

# %% [markdown]
# ### 2.4.3 Adjust Video Contrast
#
# Changing the contrast can enhance or diminish the differences in intensity between pixels, which can bring out or supress certain features in a video. This can make the model more resilien to variations in contrast that may occur in the real-world scenarios.

# %%
# Function to decrease the contrast of the video
def change_video_contrast(input_video_path, output_video_path, contrast_adjustment):
    '''
    Flip the video file horizontally

    Args:
    input_video_path: path of the video file
    output_video_path: path of the destination folder to write to
    contrast_adjustment: factor to increase contrast a postive number decreases the contrast,
                                                     a negative number increases the contrast
    '''

    # Open the input video file
    cap = cv2.VideoCapture(input_video_path)

    # Define the codec and create VideoWriter object
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_video_path, fourcc, cap.get(cv2.CAP_PROP_FPS),
                          (int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)), int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))))

    # Loop through each frame in the video
    while True:
        ret, frame = cap.read() # read the frame from the video
        if not ret: # if cannot read frame, break loop
            break

        # increase contrast
        f = (1.0 - contrast_adjustment / 100.0)  # calculate contrast factor

        # change the contrast
        frame = cv2.addWeighted(frame, f, frame, 0, 128*(1-f)) 

        # write the adjusted contrast frame to the output video
        out.write(frame)

    # Release video capture object
    cap.release()

    # release video write object
    out.release()
    # print("Video contrast decreased and saved to", output_video_path) # debug



# function to augment all video clips within the folder and action
def augment_by_contrast(label:str, save_folder:str, contrast_adjustment: float):
    '''
    increase the contrast in a given folder by passing
    the following arguments

    Args:
    label: The label of the video category to process.
    save_folder: the folder name: 'train_data', 'test_data', 'val_data'
    '''

    # General path of video files
    GENERAL_PATH = '../videos/'

    # Construct  the path to the folder containing the labeled videos
    LABEL_PATH = os.path.join(GENERAL_PATH, save_folder + '/output/' + label + '/')

    # Define the output directory where videos will be saved
    OUTPUT_DIR = os.path.join('../videos/', save_folder + '/output/'  + label + '/videos_to_annotate/')

    # create a destination folder and check if it exists
    os.makedirs(OUTPUT_DIR, exist_ok=True)  # Ensure the output directory exists

    # intialize counter for file naming
    count = 1

    # get a list of video files in the labelled folder
    video_files = [f for f in os.listdir(LABEL_PATH) if f.endswith('.mp4')]

    # name logic to prevent conflicting naming of video file
    if contrast_adjustment > 0:
        contrast = 'decrease_contrast'
    elif contrast_adjustment < 0:
        contrast = 'increase_contrast'
    else:
        print('please choose a contrast greater than or less than 0')
    
    # loop through each video in the video folder
    for vid in video_files:
        
        # construct the full path to the input video
        VIDEO_PATH = os.path.join(LABEL_PATH, vid)
        # print('Reducing Contrast: ', vid) # debug
        logging.info('Video augmented by reducing the contrast: %s', vid) # write to logging file

        # Ensure the output filename does not conflict and has the correct extension
        OUT_PATH = os.path.join(OUTPUT_DIR, f'{label}_{contrast}_{count}.mp4')

        # call the function to adjust the contrast of the video
        change_video_contrast(VIDEO_PATH, OUT_PATH, contrast_adjustment)

        count += 1 # increment the count
        

    return f'All video files have been augmented by reducing contrast'

# %% [markdown]
# ### 2.4.4 Augment by Shearing
#
# Shearing left or right introduces distortion that simulates the effects of perspective changes or camera movements, making the model more robust to such variations. This encourages the model to learn the signed words from different angles or viewpoints, improving its ability to recognize objects from diverse perspectives.

# %%
# Function to flip shear a video

def shear_video(input_video_path, output_video_path, shear_factor):
    '''
    Shear video clip horizontally

    Args:
    input_video_path: path of the video file
    output_video_path: path of the destination folder to write to
    shear_factor: a float number, positive value will be sheared to the right
                                  negative value will be sheared to the left
    '''

    # Open the input video file
    cap = cv2.VideoCapture(input_video_path)

    # Define the codec and create VideoWriter object
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')

    fps = cap.get(cv2.CAP_PROP_FPS) # get fps
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)) # get frame width
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT)) # get frame height

    # Output video writer
    out = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))

    # Loop through each frame in the video
    while True:
        ret, frame = cap.read() # read the frame from the video
        if not ret: # if cannot read frame, break loop
            break

        # Transformation matrix for shearing
        M = np.array([
            [1, shear_factor, 0],
            [0, 1, 0]
        ], dtype=float)

        # Apply the shearing transformation
        sheared_frame = cv2.warpAffine(frame, M, (width + int(shear_factor * height), height))

        # Since the image might get cut off on the right, we need to resize it back to original
        sheared_frame = cv2.resize(sheared_frame, (width, height))

        # Write the transformed frame
        out.write(sheared_frame)

    # Release video capture object
    cap.release()
    # release video write object
    out.release()
    # print("Video sheared and saved to", output_video_path) # debug


# function to augment all video clips within the folder and action
def augment_by_shearing(label:str, save_folder:str, shear_factor: float):
    '''
    Shear the videos in a given folder by passing
    the following arguments

    Args:
    label: The label of the video category to process.
    save_folder: the folder name: 'train_data', 'test_data', 'val_data'
    shear_factor: the amount to shear with positive shear to the right, and negative shear to the left
    '''

    # General path of video files
    GENERAL_PATH = '../videos/'

    # Construct  the path to the folder containing the labeled videos
    LABEL_PATH = os.path.join(GENERAL_PATH, save_folder + '/output/' + label + '/')

    # Define the output directory where videos will be saved
    OUTPUT_DIR = os.path.join('../videos/', save_folder + '/output/'  + label + '/videos_to_annotate/')

    # create a destination folder and check if it exists
    os.makedirs(OUTPUT_DIR, exist_ok=True)  # Ensure the output directory exists

    # intialize counter for file naming
    count = 1
    
    # get a list of video files in the labelled folder
    video_files = [f for f in os.listdir(LABEL_PATH) if f.endswith('.mp4')]

    # name logic to prevent conflicting naming of video file
    if shear_factor > 0:
        shear = 'shear_positive'
    elif shear_factor < 0:
        shear = 'shear_negative'
    else:
        print('please choose a shear factor greater than or less than 0')
    
    # loop through each video in the video folder
    for vid in video_files:
        
        # construct the full path to the input video
        VIDEO_PATH = os.path.join(LABEL_PATH, vid)
        # print('Shearing: ', vid) # debug
        logging.info('Video augmented by shearing: %s', vid) # write into logging file

        # Ensure the output filename does not conflict and has the correct extension
        OUT_PATH = os.path.join(OUTPUT_DIR, f'{label}_{shear}_{count}.mp4')

        # call the function to shear the video
        shear_video(VIDEO_PATH, OUT_PATH, shear_factor)
        count += 1 # increment the count
        

    return f'All video files have been augmented by shearing'

# %% [markdown]
# ### 2.4.5 Gaussian Blur
#
# Gaussian blur smooths out fine details in the video, which can help the model focus on more prominent features and reduce sensitivity to noise. This would mimic the effect of motion blur that may occur due to camera or the signer's motion, making the model more robust.

# %%
# function to apply Gaussian blur to the video
def blur_video(input_video_path, output_video_path, kernel_size=(5, 5)):
    """
    Applies Gaussian blur to each frame of the video.
    
    Args:
    input_video_path (str): Path to the input video file.
    output_video_path (str): Path to the output video file.
    kernel_size (tuple): Size of the kernel used for the Gaussian blur.
    """
    # Open the input video file
    cap = cv2.VideoCapture(input_video_path)

    # Define the codec and create VideoWriter object
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    fps = cap.get(cv2.CAP_PROP_FPS) # get the fps
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)) # get the frame width
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT)) # get the frame height

    # Output video writer
    out = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))

    # Loop through each frame in the video
    while True:
        ret, frame = cap.read() # read the frame from the video
        if not ret: # if cannot read frame, break loop
            break

        # Apply Gaussian blur to the frame
        blurred_frame = cv2.GaussianBlur(frame, kernel_size, 0)

        # Write the blurred frame to the output video
        out.write(blurred_frame)

    # Release video capture object
    cap.release()
    # release video write object
    out.release()
    # print("Video blurred and saved to", output_video_path) # debug


# function to augment all video clips within the folder and action
def augment_by_blur(label:str, save_folder:str):
    '''
    Apply Gaussian Blur to the videos in the folder directory
    Args:
    label: The label of the video category to process.
    save_folder: the folder name: 'train_data', 'test_data', 'val_data'
    '''

    # General path of video files
    GENERAL_PATH = '../videos/'

    # Construct  the path to the folder containing the labeled videos
    LABEL_PATH = os.path.join(GENERAL_PATH, save_folder + '/output/' + label + '/')

    # Define the output directory where videos will be saved
    OUTPUT_DIR = os.path.join('../videos/', save_folder + '/output/'  + label + '/videos_to_annotate/')

    # create a destination folder and check if it exists
    os.makedirs(OUTPUT_DIR, exist_ok=True)  # Ensure the output directory exists

    # intialize counter for file naming
    count = 1

    # only read video files and not the created nested folder
    video_files = [f for f in os.listdir(LABEL_PATH) if f.endswith('.mp4')]
    
    # loop through each video in the video folder
    for vid in video_files:
        
        # construct the full path to the input video
        VIDEO_PATH = os.path.join(LABEL_PATH, vid)
        # print('Applying Gaussian blur: ', vid) # debug
        logging.info('Video augmented by applying Gaussian Blur: %s', vid) # write to logging file

        # Ensure the output filename does not conflict and has the correct extension
        OUT_PATH = os.path.join(OUTPUT_DIR, f'{label}_Gblur_{count}.mp4')

        # call the function to apply Gaussian blue
        blur_video(VIDEO_PATH, OUT_PATH)
        
        count += 1 # increment the count
        

    return f'All video files have been augmented by applying Gaussian Blur'

# %% [markdown]
# ### 2.4.6 Apply augmentation to the video files
#
# With the above defined function to augment the video files, we are now able to use a single loop to apply all the augmentation function to the video files.

# %%
folder_list = ['train_data', 'test_data', 'val_data']

for vid in first_three:
    for folder in folder_list:
        augment_by_flip(vid,folder) # flip the clip horizontally
        augment_by_darken(vid,folder) # reduce the brightness
        augment_by_contrast(vid,folder, 30) # decrease the contrast
        augment_by_contrast(vid,folder, -30) # increase the contrast
        augment_by_shearing(vid,folder, 0.1) # shear to the right
        augment_by_shearing(vid,folder, -0.1) # shear to the left
        augment_by_blur(vid,folder) # apply gaussian blur
# Out:
# INFO - Video augmented by flipping: please_1.mp4
# INFO - Video augmented by flipping: please_10.mp4
# INFO - Video augmented by flipping: please_11.mp4
# INFO - Video augmented by flipping: please_12.mp4
# INFO - Video augmented by flipping: please_13.mp4
# INFO - Video augmented by flipping: please_14.mp4
# INFO - Video augmented by flipping: please_15.mp4
# INFO - Video augmented by flipping: please_16.mp4
# INFO - Video augmented by flipping: please_17.mp4
# INFO - Video augmented by flipping: please_18.mp4
# INFO - Video augmented by flipping: please_19.mp4
# INFO - Video augmented by flipping: please_2.mp4
# INFO - Video augmented by flipping: please_20.mp4
# INFO - Video augmented by flipping: please_21.mp4
# INFO - Video augmented by flipping: please_22.mp4
# INFO - Video augmented by flipping: please_23.mp4
# INFO - Video augmented by flipping: please_24.mp4
# INFO - Video augmented by flipping: please_25.mp4
# INFO - Video augmented by flipping: please_26.mp4
# INFO - Video augmented by flipping: please_27.mp4
# INFO - Video augmented by flipping: please_28.mp4
# INFO - Video augmented by flipping: please_29.mp4
# INFO - Video augmented by flipping: please_3.mp4
# INFO - Video augmented by flipping: please_4.mp4
# INFO - Video augmented by flipping: please_5.mp4
# INFO - Video augmented by flipping: please_6.mp4
# INFO - Video augmented by flipping: please_7.mp4
# INFO - Video augmented by flipping: please_8.mp4
# INFO - Video augmented by flipping: please_9.mp4
# INFO - Video augmented by reducing brightness: please_1.mp4
# INFO - Video augmented by reducing brightness: please_10.mp4
# INFO - Video augmented by reducing brightness: please_11.mp4
# INFO - Video augmented by reducing brightness: please_12.mp4
# INFO - Video augmented by reducing brightness: please_13.mp4
# INFO - Video augmented by reducing brightness: please_14.mp4
# INFO - Video augmented by reducing brightness: please_15.mp4
# INFO - Video augmented by reducing brightness: please_16.mp4
# INFO - Video augmented by reducing brightness: please_17.mp4
# INFO - Video augmented by reducing brightness: please_18.mp4
# INFO - Video augmented by reducing brightness: please_19.mp4
# INFO - Video augmented by reducing brightness: please_2.mp4
# INFO - Video augmented by reducing brightness: please_20.mp4
# INFO - Video augmented by reducing brightness: please_21.mp4
# INFO - Video augmented by reducing brightness: please_22.mp4
# INFO - Video augmented by reducing brightness: please_23.mp4
# INFO - Video augmented by reducing brightness: please_24.mp4
# INFO - Video augmented by reducing brightness: please_25.mp4
# INFO - Video augmented by reducing brightness: please_26.mp4
# INFO - Video augmented by reducing brightness: please_27.mp4
# INFO - Video augmented by reducing brightness: please_28.mp4
# INFO - Video augmented by reducing brightness: please_29.mp4
# INFO - Video augmented by reducing brightness: please_3.mp4
# INFO - Video augmented by reducing brightness: please_4.mp4
# INFO - Video augmented by reducing brightness: please_5.mp4
# INFO - Video augmented by reducing brightness: please_6.mp4
# INFO - Video augmented by reducing brightness: please_7.mp4
# INFO - Video augmented by reducing brightness: please_8.mp4
# INFO - Video augmented by reducing brightness: please_9.mp4
# INFO - Video augmented by reducing the contrast: please_1.mp4
# INFO - Video augmented by reducing the contrast: please_10.mp4
# INFO - Video augmented by reducing the contrast: please_11.mp4
# INFO - Video augmented by reducing the contrast: please_12.mp4
# INFO - Video augmented by reducing the contrast: please_13.mp4
# INFO - Video augmented by reducing the contrast: please_14.mp4
# INFO - Video augmented by reducing the contrast: please_15.mp4
# INFO - Video augmented by reducing the contrast: please_16.mp4
# INFO - Video augmented by reducing the contrast: please_17.mp4
# INFO - Video augmented by reducing the contrast: please_18.mp4
# INFO - Video augmented by reducing the contrast: please_19.mp4
# INFO - Video augmented by reducing the contrast: please_2.mp4
# INFO - Video augmented by reducing the contrast: please_20.mp4
# INFO - Video augmented by reducing the contrast: please_21.mp4
# INFO - Video augmented by reducing the contrast: please_22.mp4
# INFO - Video augmented by reducing the contrast: please_23.mp4
# INFO - Video augmented by reducing the contrast: please_24.mp4
# INFO - Video augmented by reducing the contrast: please_25.mp4
# INFO - Video augmented by reducing the contrast: please_26.mp4
# INFO - Video augmented by reducing the contrast: please_27.mp4
# INFO - Video augmented by reducing the contrast: please_28.mp4
# INFO - Video augmented by reducing the contrast: please_29.mp4
# INFO - Video augmented by reducing the contrast: please_3.mp4
# INFO - Video augmented by reducing the contrast: please_4.mp4
# INFO - Video augmented by reducing the contrast: please_5.mp4
# INFO - Video augmented by reducing the contrast: please_6.mp4
# INFO - Video augmented by reducing the contrast: please_7.mp4
# INFO - Video augmented by reducing the contrast: please_8.mp4
# INFO - Video augmented by reducing the contrast: please_9.mp4
# INFO - Video augmented by reducing the contrast: please_1.mp4
# INFO - Video augmented by reducing the contrast: please_10.mp4
# INFO - Video augmented by reducing the contrast: please_11.mp4
# INFO - Video augmented by reducing the contrast: please_12.mp4
# INFO - Video augmented by reducing the contrast: please_13.mp4
# INFO - Video augmented by reducing the contrast: please_14.mp4
# INFO - Video augmented by reducing the contrast: please_15.mp4
# INFO - Video augmented by reducing the contrast: please_16.mp4
# INFO - Video augmented by reducing the contrast: please_17.mp4
# INFO - Video augmented by reducing the contrast: please_18.mp4
# INFO - Video augmented by reducing the contrast: please_19.mp4
# INFO - Video augmented by reducing the contrast: please_2.mp4
# INFO - Video augmented by reducing the contrast: please_20.mp4
# INFO - Video augmented by reducing the contrast: please_21.mp4
# INFO - Video augmented by reducing the contrast: please_22.mp4
# INFO - Video augmented by reducing the contrast: please_23.mp4
# INFO - Video augmented by reducing the contrast: please_24.mp4
# INFO - Video augmented by reducing the contrast: please_25.mp4
# INFO - Video augmented by reducing the contrast: please_26.mp4
# INFO - Video augmented by reducing the contrast: please_27.mp4
# INFO - Video augmented by reducing the contrast: please_28.mp4
# INFO - Video augmented by reducing the contrast: please_29.mp4
# INFO - Video augmented by reducing the contrast: please_3.mp4
# INFO - Video augmented by reducing the contrast: please_4.mp4
# INFO - Video augmented by reducing the contrast: please_5.mp4
# INFO - Video augmented by reducing the contrast: please_6.mp4
# INFO - Video augmented by reducing the contrast: please_7.mp4
# INFO - Video augmented by reducing the contrast: please_8.mp4
# INFO - Video augmented by reducing the contrast: please_9.mp4
# INFO - Video augmented by shearing: please_1.mp4
# INFO - Video augmented by shearing: please_10.mp4
# INFO - Video augmented by shearing: please_11.mp4
# INFO - Video augmented by shearing: please_12.mp4
# INFO - Video augmented by shearing: please_13.mp4
# INFO - Video augmented by shearing: please_14.mp4
# INFO - Video augmented by shearing: please_15.mp4
# INFO - Video augmented by shearing: please_16.mp4
# INFO - Video augmented by shearing: please_17.mp4
# INFO - Video augmented by shearing: please_18.mp4
# INFO - Video augmented by shearing: please_19.mp4
# INFO - Video augmented by shearing: please_2.mp4
# INFO - Video augmented by shearing: please_20.mp4
# INFO - Video augmented by shearing: please_21.mp4
# INFO - Video augmented by shearing: please_22.mp4
# INFO - Video augmented by shearing: please_23.mp4
# INFO - Video augmented by shearing: please_24.mp4
# INFO - Video augmented by shearing: please_25.mp4
# INFO - Video augmented by shearing: please_26.mp4
# INFO - Video augmented by shearing: please_27.mp4
# INFO - Video augmented by shearing: please_28.mp4
# INFO - Video augmented by shearing: please_29.mp4
# INFO - Video augmented by shearing: please_3.mp4
# INFO - Video augmented by shearing: please_4.mp4
# INFO - Video augmented by shearing: please_5.mp4
# INFO - Video augmented by shearing: please_6.mp4
# INFO - Video augmented by shearing: please_7.mp4
# INFO - Video augmented by shearing: please_8.mp4
# INFO - Video augmented by shearing: please_9.mp4
# INFO - Video augmented by shearing: please_1.mp4
# INFO - Video augmented by shearing: please_10.mp4
# INFO - Video augmented by shearing: please_11.mp4
# INFO - Video augmented by shearing: please_12.mp4
# INFO - Video augmented by shearing: please_13.mp4
# INFO - Video augmented by shearing: please_14.mp4
# INFO - Video augmented by shearing: please_15.mp4
# INFO - Video augmented by shearing: please_16.mp4
# INFO - Video augmented by shearing: please_17.mp4
# INFO - Video augmented by shearing: please_18.mp4
# INFO - Video augmented by shearing: please_19.mp4
# INFO - Video augmented by shearing: please_2.mp4
# INFO - Video augmented by shearing: please_20.mp4
# INFO - Video augmented by shearing: please_21.mp4
# INFO - Video augmented by shearing: please_22.mp4
# INFO - Video augmented by shearing: please_23.mp4
# INFO - Video augmented by shearing: please_24.mp4
# INFO - Video augmented by shearing: please_25.mp4
# INFO - Video augmented by shearing: please_26.mp4
# INFO - Video augmented by shearing: please_27.mp4
# INFO - Video augmented by shearing: please_28.mp4
# INFO - Video augmented by shearing: please_29.mp4
# INFO - Video augmented by shearing: please_3.mp4
# INFO - Video augmented by shearing: please_4.mp4
# INFO - Video augmented by shearing: please_5.mp4
# INFO - Video augmented by shearing: please_6.mp4
# INFO - Video augmented by shearing: please_7.mp4
# INFO - Video augmented by shearing: please_8.mp4
# INFO - Video augmented by shearing: please_9.mp4
# INFO - Video augmented by applying Gaussian Blur: please_1.mp4
# INFO - Video augmented by applying Gaussian Blur: please_10.mp4
# INFO - Video augmented by applying Gaussian Blur: please_11.mp4
# INFO - Video augmented by applying Gaussian Blur: please_12.mp4
# INFO - Video augmented by applying Gaussian Blur: please_13.mp4
# INFO - Video augmented by applying Gaussian Blur: please_14.mp4
# INFO - Video augmented by applying Gaussian Blur: please_15.mp4
# INFO - Video augmented by applying Gaussian Blur: please_16.mp4
# INFO - Video augmented by applying Gaussian Blur: please_17.mp4
# INFO - Video augmented by applying Gaussian Blur: please_18.mp4
# INFO - Video augmented by applying Gaussian Blur: please_19.mp4
# INFO - Video augmented by applying Gaussian Blur: please_2.mp4
# INFO - Video augmented by applying Gaussian Blur: please_20.mp4
# INFO - Video augmented by applying Gaussian Blur: please_21.mp4
# INFO - Video augmented by applying Gaussian Blur: please_22.mp4
# INFO - Video augmented by applying Gaussian Blur: please_23.mp4
# INFO - Video augmented by applying Gaussian Blur: please_24.mp4
# INFO - Video augmented by applying Gaussian Blur: please_25.mp4
# INFO - Video augmented by applying Gaussian Blur: please_26.mp4
# INFO - Video augmented by applying Gaussian Blur: please_27.mp4
# INFO - Video augmented by applying Gaussian Blur: please_28.mp4
# INFO - Video augmented by applying Gaussian Blur: please_29.mp4
# INFO - Video augmented by applying Gaussian Blur: please_3.mp4
# INFO - Video augmented by applying Gaussian Blur: please_4.mp4
# INFO - Video augmented by applying Gaussian Blur: please_5.mp4
# INFO - Video augmented by applying Gaussian Blur: please_6.mp4
# INFO - Video augmented by applying Gaussian Blur: please_7.mp4
# INFO - Video augmented by applying Gaussian Blur: please_8.mp4
# INFO - Video augmented by applying Gaussian Blur: please_9.mp4
# INFO - Video augmented by flipping: please_1.mp4
# INFO - Video augmented by flipping: please_2.mp4
# INFO - Video augmented by flipping: please_3.mp4
# INFO - Video augmented by reducing brightness: please_1.mp4
# INFO - Video augmented by reducing brightness: please_2.mp4
# INFO - Video augmented by reducing brightness: please_3.mp4
# INFO - Video augmented by reducing the contrast: please_1.mp4
# INFO - Video augmented by reducing the contrast: please_2.mp4
# INFO - Video augmented by reducing the contrast: please_3.mp4
# INFO - Video augmented by reducing the contrast: please_1.mp4
# INFO - Video augmented by reducing the contrast: please_2.mp4
# INFO - Video augmented by reducing the contrast: please_3.mp4
# INFO - Video augmented by shearing: please_1.mp4
# INFO - Video augmented by shearing: please_2.mp4
# INFO - Video augmented by shearing: please_3.mp4
# INFO - Video augmented by shearing: please_1.mp4
# INFO - Video augmented by shearing: please_2.mp4
# INFO - Video augmented by shearing: please_3.mp4
# INFO - Video augmented by applying Gaussian Blur: please_1.mp4
# INFO - Video augmented by applying Gaussian Blur: please_2.mp4
# INFO - Video augmented by applying Gaussian Blur: please_3.mp4
# INFO - Video augmented by flipping: please_1.mp4
# INFO - Video augmented by flipping: please_2.mp4
# INFO - Video augmented by flipping: please_3.mp4
# INFO - Video augmented by reducing brightness: please_1.mp4
# INFO - Video augmented by reducing brightness: please_2.mp4
# INFO - Video augmented by reducing brightness: please_3.mp4
# INFO - Video augmented by reducing the contrast: please_1.mp4
# INFO - Video augmented by reducing the contrast: please_2.mp4
# INFO - Video augmented by reducing the contrast: please_3.mp4
# INFO - Video augmented by reducing the contrast: please_1.mp4
# INFO - Video augmented by reducing the contrast: please_2.mp4
# INFO - Video augmented by reducing the contrast: please_3.mp4
# INFO - Video augmented by shearing: please_1.mp4
# INFO - Video augmented by shearing: please_2.mp4
# INFO - Video augmented by shearing: please_3.mp4
# INFO - Video augmented by shearing: please_1.mp4
# INFO - Video augmented by shearing: please_2.mp4
# INFO - Video augmented by shearing: please_3.mp4
# INFO - Video augmented by applying Gaussian Blur: please_1.mp4
# INFO - Video augmented by applying Gaussian Blur: please_2.mp4
# INFO - Video augmented by applying Gaussian Blur: please_3.mp4
# INFO - Video augmented by flipping: sorry_1.mp4
# INFO - Video augmented by flipping: sorry_10.mp4
# INFO - Video augmented by flipping: sorry_11.mp4
# INFO - Video augmented by flipping: sorry_12.mp4
# INFO - Video augmented by flipping: sorry_13.mp4
# INFO - Video augmented by flipping: sorry_14.mp4
# INFO - Video augmented by flipping: sorry_15.mp4
# INFO - Video augmented by flipping: sorry_16.mp4
# INFO - Video augmented by flipping: sorry_17.mp4
# INFO - Video augmented by flipping: sorry_18.mp4
# INFO - Video augmented by flipping: sorry_2.mp4
# INFO - Video augmented by flipping: sorry_3.mp4
# INFO - Video augmented by flipping: sorry_4.mp4
# INFO - Video augmented by flipping: sorry_5.mp4
# INFO - Video augmented by flipping: sorry_6.mp4
# INFO - Video augmented by flipping: sorry_7.mp4
# INFO - Video augmented by flipping: sorry_8.mp4
# INFO - Video augmented by flipping: sorry_9.mp4
# INFO - Video augmented by reducing brightness: sorry_1.mp4
# INFO - Video augmented by reducing brightness: sorry_10.mp4
# INFO - Video augmented by reducing brightness: sorry_11.mp4
# INFO - Video augmented by reducing brightness: sorry_12.mp4
# INFO - Video augmented by reducing brightness: sorry_13.mp4
# INFO - Video augmented by reducing brightness: sorry_14.mp4
# INFO - Video augmented by reducing brightness: sorry_15.mp4
# INFO - Video augmented by reducing brightness: sorry_16.mp4
# INFO - Video augmented by reducing brightness: sorry_17.mp4
# INFO - Video augmented by reducing brightness: sorry_18.mp4
# INFO - Video augmented by reducing brightness: sorry_2.mp4
# INFO - Video augmented by reducing brightness: sorry_3.mp4
# INFO - Video augmented by reducing brightness: sorry_4.mp4
# INFO - Video augmented by reducing brightness: sorry_5.mp4
# INFO - Video augmented by reducing brightness: sorry_6.mp4
# INFO - Video augmented by reducing brightness: sorry_7.mp4
# INFO - Video augmented by reducing brightness: sorry_8.mp4
# INFO - Video augmented by reducing brightness: sorry_9.mp4
# INFO - Video augmented by reducing the contrast: sorry_1.mp4
# INFO - Video augmented by reducing the contrast: sorry_10.mp4
# INFO - Video augmented by reducing the contrast: sorry_11.mp4
# INFO - Video augmented by reducing the contrast: sorry_12.mp4
# INFO - Video augmented by reducing the contrast: sorry_13.mp4
# INFO - Video augmented by reducing the contrast: sorry_14.mp4
# INFO - Video augmented by reducing the contrast: sorry_15.mp4
# INFO - Video augmented by reducing the contrast: sorry_16.mp4
# INFO - Video augmented by reducing the contrast: sorry_17.mp4
# INFO - Video augmented by reducing the contrast: sorry_18.mp4
# INFO - Video augmented by reducing the contrast: sorry_2.mp4
# INFO - Video augmented by reducing the contrast: sorry_3.mp4
# INFO - Video augmented by reducing the contrast: sorry_4.mp4
# INFO - Video augmented by reducing the contrast: sorry_5.mp4
# INFO - Video augmented by reducing the contrast: sorry_6.mp4
# INFO - Video augmented by reducing the contrast: sorry_7.mp4
# INFO - Video augmented by reducing the contrast: sorry_8.mp4
# INFO - Video augmented by reducing the contrast: sorry_9.mp4
# INFO - Video augmented by reducing the contrast: sorry_1.mp4
# INFO - Video augmented by reducing the contrast: sorry_10.mp4
# INFO - Video augmented by reducing the contrast: sorry_11.mp4
# INFO - Video augmented by reducing the contrast: sorry_12.mp4
# INFO - Video augmented by reducing the contrast: sorry_13.mp4
# INFO - Video augmented by reducing the contrast: sorry_14.mp4
# INFO - Video augmented by reducing the contrast: sorry_15.mp4
# INFO - Video augmented by reducing the contrast: sorry_16.mp4
# INFO - Video augmented by reducing the contrast: sorry_17.mp4
# INFO - Video augmented by reducing the contrast: sorry_18.mp4
# INFO - Video augmented by reducing the contrast: sorry_2.mp4
# INFO - Video augmented by reducing the contrast: sorry_3.mp4
# INFO - Video augmented by reducing the contrast: sorry_4.mp4
# INFO - Video augmented by reducing the contrast: sorry_5.mp4
# INFO - Video augmented by reducing the contrast: sorry_6.mp4
# INFO - Video augmented by reducing the contrast: sorry_7.mp4
# INFO - Video augmented by reducing the contrast: sorry_8.mp4
# INFO - Video augmented by reducing the contrast: sorry_9.mp4
# INFO - Video augmented by shearing: sorry_1.mp4
# INFO - Video augmented by shearing: sorry_10.mp4
# INFO - Video augmented by shearing: sorry_11.mp4
# INFO - Video augmented by shearing: sorry_12.mp4
# INFO - Video augmented by shearing: sorry_13.mp4
# INFO - Video augmented by shearing: sorry_14.mp4
# INFO - Video augmented by shearing: sorry_15.mp4
# INFO - Video augmented by shearing: sorry_16.mp4
# INFO - Video augmented by shearing: sorry_17.mp4
# INFO - Video augmented by shearing: sorry_18.mp4
# INFO - Video augmented by shearing: sorry_2.mp4
# INFO - Video augmented by shearing: sorry_3.mp4
# INFO - Video augmented by shearing: sorry_4.mp4
# INFO - Video augmented by shearing: sorry_5.mp4
# INFO - Video augmented by shearing: sorry_6.mp4
# INFO - Video augmented by shearing: sorry_7.mp4
# INFO - Video augmented by shearing: sorry_8.mp4
# INFO - Video augmented by shearing: sorry_9.mp4
# INFO - Video augmented by shearing: sorry_1.mp4
# INFO - Video augmented by shearing: sorry_10.mp4
# INFO - Video augmented by shearing: sorry_11.mp4
# INFO - Video augmented by shearing: sorry_12.mp4
# INFO - Video augmented by shearing: sorry_13.mp4
# INFO - Video augmented by shearing: sorry_14.mp4
# INFO - Video augmented by shearing: sorry_15.mp4
# INFO - Video augmented by shearing: sorry_16.mp4
# INFO - Video augmented by shearing: sorry_17.mp4
# INFO - Video augmented by shearing: sorry_18.mp4
# INFO - Video augmented by shearing: sorry_2.mp4
# INFO - Video augmented by shearing: sorry_3.mp4
# INFO - Video augmented by shearing: sorry_4.mp4
# INFO - Video augmented by shearing: sorry_5.mp4
# INFO - Video augmented by shearing: sorry_6.mp4
# INFO - Video augmented by shearing: sorry_7.mp4
# INFO - Video augmented by shearing: sorry_8.mp4
# INFO - Video augmented by shearing: sorry_9.mp4
# INFO - Video augmented by applying Gaussian Blur: sorry_1.mp4
# INFO - Video augmented by applying Gaussian Blur: sorry_10.mp4
# INFO - Video augmented by applying Gaussian Blur: sorry_11.mp4
# INFO - Video augmented by applying Gaussian Blur: sorry_12.mp4
# INFO - Video augmented by applying Gaussian Blur: sorry_13.mp4
# INFO - Video augmented by applying Gaussian Blur: sorry_14.mp4
# INFO - Video augmented by applying Gaussian Blur: sorry_15.mp4
# INFO - Video augmented by applying Gaussian Blur: sorry_16.mp4
# INFO - Video augmented by applying Gaussian Blur: sorry_17.mp4
# INFO - Video augmented by applying Gaussian Blur: sorry_18.mp4
# INFO - Video augmented by applying Gaussian Blur: sorry_2.mp4
# INFO - Video augmented by applying Gaussian Blur: sorry_3.mp4
# INFO - Video augmented by applying Gaussian Blur: sorry_4.mp4
# INFO - Video augmented by applying Gaussian Blur: sorry_5.mp4
# INFO - Video augmented by applying Gaussian Blur: sorry_6.mp4
# INFO - Video augmented by applying Gaussian Blur: sorry_7.mp4
# INFO - Video augmented by applying Gaussian Blur: sorry_8.mp4
# INFO - Video augmented by applying Gaussian Blur: sorry_9.mp4
# INFO - Video augmented by flipping: sorry_1.mp4
# INFO - Video augmented by reducing brightness: sorry_1.mp4
# INFO - Video augmented by reducing the contrast: sorry_1.mp4
# INFO - Video augmented by reducing the contrast: sorry_1.mp4
# INFO - Video augmented by shearing: sorry_1.mp4
# INFO - Video augmented by shearing: sorry_1.mp4
# INFO - Video augmented by applying Gaussian Blur: sorry_1.mp4
# INFO - Video augmented by flipping: sorry_1.mp4
# INFO - Video augmented by flipping: sorry_10.mp4
# INFO - Video augmented by flipping: sorry_2.mp4
# INFO - Video augmented by flipping: sorry_3.mp4
# INFO - Video augmented by flipping: sorry_4.mp4
# INFO - Video augmented by flipping: sorry_5.mp4
# INFO - Video augmented by flipping: sorry_6.mp4
# INFO - Video augmented by flipping: sorry_7.mp4
# INFO - Video augmented by flipping: sorry_8.mp4
# INFO - Video augmented by flipping: sorry_9.mp4
# INFO - Video augmented by reducing brightness: sorry_1.mp4
# INFO - Video augmented by reducing brightness: sorry_10.mp4
# INFO - Video augmented by reducing brightness: sorry_2.mp4
# INFO - Video augmented by reducing brightness: sorry_3.mp4
# INFO - Video augmented by reducing brightness: sorry_4.mp4
# INFO - Video augmented by reducing brightness: sorry_5.mp4
# INFO - Video augmented by reducing brightness: sorry_6.mp4
# INFO - Video augmented by reducing brightness: sorry_7.mp4
# INFO - Video augmented by reducing brightness: sorry_8.mp4
# INFO - Video augmented by reducing brightness: sorry_9.mp4
# INFO - Video augmented by reducing the contrast: sorry_1.mp4
# INFO - Video augmented by reducing the contrast: sorry_10.mp4
# INFO - Video augmented by reducing the contrast: sorry_2.mp4
# INFO - Video augmented by reducing the contrast: sorry_3.mp4
# INFO - Video augmented by reducing the contrast: sorry_4.mp4
# INFO - Video augmented by reducing the contrast: sorry_5.mp4
# INFO - Video augmented by reducing the contrast: sorry_6.mp4
# INFO - Video augmented by reducing the contrast: sorry_7.mp4
# INFO - Video augmented by reducing the contrast: sorry_8.mp4
# INFO - Video augmented by reducing the contrast: sorry_9.mp4
# INFO - Video augmented by reducing the contrast: sorry_1.mp4
# INFO - Video augmented by reducing the contrast: sorry_10.mp4
# INFO - Video augmented by reducing the contrast: sorry_2.mp4
# INFO - Video augmented by reducing the contrast: sorry_3.mp4
# INFO - Video augmented by reducing the contrast: sorry_4.mp4
# INFO - Video augmented by reducing the contrast: sorry_5.mp4
# INFO - Video augmented by reducing the contrast: sorry_6.mp4
# INFO - Video augmented by reducing the contrast: sorry_7.mp4
# INFO - Video augmented by reducing the contrast: sorry_8.mp4
# INFO - Video augmented by reducing the contrast: sorry_9.mp4
# INFO - Video augmented by shearing: sorry_1.mp4
# INFO - Video augmented by shearing: sorry_10.mp4
# INFO - Video augmented by shearing: sorry_2.mp4
# INFO - Video augmented by shearing: sorry_3.mp4
# INFO - Video augmented by shearing: sorry_4.mp4
# INFO - Video augmented by shearing: sorry_5.mp4
# INFO - Video augmented by shearing: sorry_6.mp4
# INFO - Video augmented by shearing: sorry_7.mp4
# INFO - Video augmented by shearing: sorry_8.mp4
# INFO - Video augmented by shearing: sorry_9.mp4
# INFO - Video augmented by shearing: sorry_1.mp4
# INFO - Video augmented by shearing: sorry_10.mp4
# INFO - Video augmented by shearing: sorry_2.mp4
# INFO - Video augmented by shearing: sorry_3.mp4
# INFO - Video augmented by shearing: sorry_4.mp4
# INFO - Video augmented by shearing: sorry_5.mp4
# INFO - Video augmented by shearing: sorry_6.mp4
# INFO - Video augmented by shearing: sorry_7.mp4
# INFO - Video augmented by shearing: sorry_8.mp4
# INFO - Video augmented by shearing: sorry_9.mp4
# INFO - Video augmented by applying Gaussian Blur: sorry_1.mp4
# INFO - Video augmented by applying Gaussian Blur: sorry_10.mp4
# INFO - Video augmented by applying Gaussian Blur: sorry_2.mp4
# INFO - Video augmented by applying Gaussian Blur: sorry_3.mp4
# INFO - Video augmented by applying Gaussian Blur: sorry_4.mp4
# INFO - Video augmented by applying Gaussian Blur: sorry_5.mp4
# INFO - Video augmented by applying Gaussian Blur: sorry_6.mp4
# INFO - Video augmented by applying Gaussian Blur: sorry_7.mp4
# INFO - Video augmented by applying Gaussian Blur: sorry_8.mp4
# INFO - Video augmented by applying Gaussian Blur: sorry_9.mp4
# INFO - Video augmented by flipping: hello_1.mp4
# INFO - Video augmented by flipping: hello_10.mp4
# INFO - Video augmented by flipping: hello_11.mp4
# INFO - Video augmented by flipping: hello_12.mp4
# INFO - Video augmented by flipping: hello_13.mp4
# INFO - Video augmented by flipping: hello_14.mp4
# INFO - Video augmented by flipping: hello_15.mp4
# INFO - Video augmented by flipping: hello_16.mp4
# INFO - Video augmented by flipping: hello_17.mp4
# INFO - Video augmented by flipping: hello_2.mp4
# INFO - Video augmented by flipping: hello_3.mp4
# INFO - Video augmented by flipping: hello_4.mp4
# INFO - Video augmented by flipping: hello_5.mp4
# INFO - Video augmented by flipping: hello_6.mp4
# INFO - Video augmented by flipping: hello_7.mp4
# INFO - Video augmented by flipping: hello_8.mp4
# INFO - Video augmented by flipping: hello_9.mp4
# INFO - Video augmented by reducing brightness: hello_1.mp4
# INFO - Video augmented by reducing brightness: hello_10.mp4
# INFO - Video augmented by reducing brightness: hello_11.mp4
# INFO - Video augmented by reducing brightness: hello_12.mp4
# INFO - Video augmented by reducing brightness: hello_13.mp4
# INFO - Video augmented by reducing brightness: hello_14.mp4
# INFO - Video augmented by reducing brightness: hello_15.mp4
# INFO - Video augmented by reducing brightness: hello_16.mp4
# INFO - Video augmented by reducing brightness: hello_17.mp4
# INFO - Video augmented by reducing brightness: hello_2.mp4
# INFO - Video augmented by reducing brightness: hello_3.mp4
# INFO - Video augmented by reducing brightness: hello_4.mp4
# INFO - Video augmented by reducing brightness: hello_5.mp4
# INFO - Video augmented by reducing brightness: hello_6.mp4
# INFO - Video augmented by reducing brightness: hello_7.mp4
# INFO - Video augmented by reducing brightness: hello_8.mp4
# INFO - Video augmented by reducing brightness: hello_9.mp4
# INFO - Video augmented by reducing the contrast: hello_1.mp4
# INFO - Video augmented by reducing the contrast: hello_10.mp4
# INFO - Video augmented by reducing the contrast: hello_11.mp4
# INFO - Video augmented by reducing the contrast: hello_12.mp4
# INFO - Video augmented by reducing the contrast: hello_13.mp4
# INFO - Video augmented by reducing the contrast: hello_14.mp4
# INFO - Video augmented by reducing the contrast: hello_15.mp4
# INFO - Video augmented by reducing the contrast: hello_16.mp4
# INFO - Video augmented by reducing the contrast: hello_17.mp4
# INFO - Video augmented by reducing the contrast: hello_2.mp4
# INFO - Video augmented by reducing the contrast: hello_3.mp4
# INFO - Video augmented by reducing the contrast: hello_4.mp4
# INFO - Video augmented by reducing the contrast: hello_5.mp4
# INFO - Video augmented by reducing the contrast: hello_6.mp4
# INFO - Video augmented by reducing the contrast: hello_7.mp4
# INFO - Video augmented by reducing the contrast: hello_8.mp4
# INFO - Video augmented by reducing the contrast: hello_9.mp4
# INFO - Video augmented by reducing the contrast: hello_1.mp4
# INFO - Video augmented by reducing the contrast: hello_10.mp4
# INFO - Video augmented by reducing the contrast: hello_11.mp4
# INFO - Video augmented by reducing the contrast: hello_12.mp4
# INFO - Video augmented by reducing the contrast: hello_13.mp4
# INFO - Video augmented by reducing the contrast: hello_14.mp4
# INFO - Video augmented by reducing the contrast: hello_15.mp4
# INFO - Video augmented by reducing the contrast: hello_16.mp4
# INFO - Video augmented by reducing the contrast: hello_17.mp4
# INFO - Video augmented by reducing the contrast: hello_2.mp4
# INFO - Video augmented by reducing the contrast: hello_3.mp4
# INFO - Video augmented by reducing the contrast: hello_4.mp4
# INFO - Video augmented by reducing the contrast: hello_5.mp4
# INFO - Video augmented by reducing the contrast: hello_6.mp4
# INFO - Video augmented by reducing the contrast: hello_7.mp4
# INFO - Video augmented by reducing the contrast: hello_8.mp4
# INFO - Video augmented by reducing the contrast: hello_9.mp4
# INFO - Video augmented by shearing: hello_1.mp4
# INFO - Video augmented by shearing: hello_10.mp4
# INFO - Video augmented by shearing: hello_11.mp4
# INFO - Video augmented by shearing: hello_12.mp4
# INFO - Video augmented by shearing: hello_13.mp4
# INFO - Video augmented by shearing: hello_14.mp4
# INFO - Video augmented by shearing: hello_15.mp4
# INFO - Video augmented by shearing: hello_16.mp4
# INFO - Video augmented by shearing: hello_17.mp4
# INFO - Video augmented by shearing: hello_2.mp4
# INFO - Video augmented by shearing: hello_3.mp4
# INFO - Video augmented by shearing: hello_4.mp4
# INFO - Video augmented by shearing: hello_5.mp4
# INFO - Video augmented by shearing: hello_6.mp4
# INFO - Video augmented by shearing: hello_7.mp4
# INFO - Video augmented by shearing: hello_8.mp4
# INFO - Video augmented by shearing: hello_9.mp4
# INFO - Video augmented by shearing: hello_1.mp4
# INFO - Video augmented by shearing: hello_10.mp4
# INFO - Video augmented by shearing: hello_11.mp4
# INFO - Video augmented by shearing: hello_12.mp4
# INFO - Video augmented by shearing: hello_13.mp4
# INFO - Video augmented by shearing: hello_14.mp4
# INFO - Video augmented by shearing: hello_15.mp4
# INFO - Video augmented by shearing: hello_16.mp4
# INFO - Video augmented by shearing: hello_17.mp4
# INFO - Video augmented by shearing: hello_2.mp4
# INFO - Video augmented by shearing: hello_3.mp4
# INFO - Video augmented by shearing: hello_4.mp4
# INFO - Video augmented by shearing: hello_5.mp4
# INFO - Video augmented by shearing: hello_6.mp4
# INFO - Video augmented by shearing: hello_7.mp4
# INFO - Video augmented by shearing: hello_8.mp4
# INFO - Video augmented by shearing: hello_9.mp4
# INFO - Video augmented by applying Gaussian Blur: hello_1.mp4
# INFO - Video augmented by applying Gaussian Blur: hello_10.mp4
# INFO - Video augmented by applying Gaussian Blur: hello_11.mp4
# INFO - Video augmented by applying Gaussian Blur: hello_12.mp4
# INFO - Video augmented by applying Gaussian Blur: hello_13.mp4
# INFO - Video augmented by applying Gaussian Blur: hello_14.mp4
# INFO - Video augmented by applying Gaussian Blur: hello_15.mp4
# INFO - Video augmented by applying Gaussian Blur: hello_16.mp4
# INFO - Video augmented by applying Gaussian Blur: hello_17.mp4
# INFO - Video augmented by applying Gaussian Blur: hello_2.mp4
# INFO - Video augmented by applying Gaussian Blur: hello_3.mp4
# INFO - Video augmented by applying Gaussian Blur: hello_4.mp4
# INFO - Video augmented by applying Gaussian Blur: hello_5.mp4
# INFO - Video augmented by applying Gaussian Blur: hello_6.mp4
# INFO - Video augmented by applying Gaussian Blur: hello_7.mp4
# INFO - Video augmented by applying Gaussian Blur: hello_8.mp4
# INFO - Video augmented by applying Gaussian Blur: hello_9.mp4
# INFO - Video augmented by flipping: hello_1.mp4
# INFO - Video augmented by flipping: hello_10.mp4
# INFO - Video augmented by flipping: hello_2.mp4
# INFO - Video augmented by flipping: hello_3.mp4
# INFO - Video augmented by flipping: hello_4.mp4
# INFO - Video augmented by flipping: hello_5.mp4
# INFO - Video augmented by flipping: hello_6.mp4
# INFO - Video augmented by flipping: hello_7.mp4
# INFO - Video augmented by flipping: hello_8.mp4
# INFO - Video augmented by flipping: hello_9.mp4
# INFO - Video augmented by reducing brightness: hello_1.mp4
# INFO - Video augmented by reducing brightness: hello_10.mp4
# INFO - Video augmented by reducing brightness: hello_2.mp4
# INFO - Video augmented by reducing brightness: hello_3.mp4
# INFO - Video augmented by reducing brightness: hello_4.mp4
# INFO - Video augmented by reducing brightness: hello_5.mp4
# INFO - Video augmented by reducing brightness: hello_6.mp4
# INFO - Video augmented by reducing brightness: hello_7.mp4
# INFO - Video augmented by reducing brightness: hello_8.mp4
# INFO - Video augmented by reducing brightness: hello_9.mp4
# INFO - Video augmented by reducing the contrast: hello_1.mp4
# INFO - Video augmented by reducing the contrast: hello_10.mp4
# INFO - Video augmented by reducing the contrast: hello_2.mp4
# INFO - Video augmented by reducing the contrast: hello_3.mp4
# INFO - Video augmented by reducing the contrast: hello_4.mp4
# INFO - Video augmented by reducing the contrast: hello_5.mp4
# INFO - Video augmented by reducing the contrast: hello_6.mp4
# INFO - Video augmented by reducing the contrast: hello_7.mp4
# INFO - Video augmented by reducing the contrast: hello_8.mp4
# INFO - Video augmented by reducing the contrast: hello_9.mp4
# INFO - Video augmented by reducing the contrast: hello_1.mp4
# INFO - Video augmented by reducing the contrast: hello_10.mp4
# INFO - Video augmented by reducing the contrast: hello_2.mp4
# INFO - Video augmented by reducing the contrast: hello_3.mp4
# INFO - Video augmented by reducing the contrast: hello_4.mp4
# INFO - Video augmented by reducing the contrast: hello_5.mp4
# INFO - Video augmented by reducing the contrast: hello_6.mp4
# INFO - Video augmented by reducing the contrast: hello_7.mp4
# INFO - Video augmented by reducing the contrast: hello_8.mp4
# INFO - Video augmented by reducing the contrast: hello_9.mp4
# INFO - Video augmented by shearing: hello_1.mp4
# INFO - Video augmented by shearing: hello_10.mp4
# INFO - Video augmented by shearing: hello_2.mp4
# INFO - Video augmented by shearing: hello_3.mp4
# INFO - Video augmented by shearing: hello_4.mp4
# INFO - Video augmented by shearing: hello_5.mp4
# INFO - Video augmented by shearing: hello_6.mp4
# INFO - Video augmented by shearing: hello_7.mp4
# INFO - Video augmented by shearing: hello_8.mp4
# INFO - Video augmented by shearing: hello_9.mp4
# INFO - Video augmented by shearing: hello_1.mp4
# INFO - Video augmented by shearing: hello_10.mp4
# INFO - Video augmented by shearing: hello_2.mp4
# INFO - Video augmented by shearing: hello_3.mp4
# INFO - Video augmented by shearing: hello_4.mp4
# INFO - Video augmented by shearing: hello_5.mp4
# INFO - Video augmented by shearing: hello_6.mp4
# INFO - Video augmented by shearing: hello_7.mp4
# INFO - Video augmented by shearing: hello_8.mp4
# INFO - Video augmented by shearing: hello_9.mp4
# INFO - Video augmented by applying Gaussian Blur: hello_1.mp4
# INFO - Video augmented by applying Gaussian Blur: hello_10.mp4
# INFO - Video augmented by applying Gaussian Blur: hello_2.mp4
# INFO - Video augmented by applying Gaussian Blur: hello_3.mp4
# INFO - Video augmented by applying Gaussian Blur: hello_4.mp4
# INFO - Video augmented by applying Gaussian Blur: hello_5.mp4
# INFO - Video augmented by applying Gaussian Blur: hello_6.mp4
# INFO - Video augmented by applying Gaussian Blur: hello_7.mp4
# INFO - Video augmented by applying Gaussian Blur: hello_8.mp4
# INFO - Video augmented by applying Gaussian Blur: hello_9.mp4
# INFO - Video augmented by flipping: hello_1.mp4
# INFO - Video augmented by flipping: hello_2.mp4
# INFO - Video augmented by flipping: hello_3.mp4
# INFO - Video augmented by flipping: hello_4.mp4
# INFO - Video augmented by flipping: hello_5.mp4
# INFO - Video augmented by reducing brightness: hello_1.mp4
# INFO - Video augmented by reducing brightness: hello_2.mp4
# INFO - Video augmented by reducing brightness: hello_3.mp4
# INFO - Video augmented by reducing brightness: hello_4.mp4
# INFO - Video augmented by reducing brightness: hello_5.mp4
# INFO - Video augmented by reducing the contrast: hello_1.mp4
# INFO - Video augmented by reducing the contrast: hello_2.mp4
# INFO - Video augmented by reducing the contrast: hello_3.mp4
# INFO - Video augmented by reducing the contrast: hello_4.mp4
# INFO - Video augmented by reducing the contrast: hello_5.mp4
# INFO - Video augmented by reducing the contrast: hello_1.mp4
# INFO - Video augmented by reducing the contrast: hello_2.mp4
# INFO - Video augmented by reducing the contrast: hello_3.mp4
# INFO - Video augmented by reducing the contrast: hello_4.mp4
# INFO - Video augmented by reducing the contrast: hello_5.mp4
# INFO - Video augmented by shearing: hello_1.mp4
# INFO - Video augmented by shearing: hello_2.mp4
# INFO - Video augmented by shearing: hello_3.mp4
# INFO - Video augmented by shearing: hello_4.mp4
# INFO - Video augmented by shearing: hello_5.mp4
# INFO - Video augmented by shearing: hello_1.mp4
# INFO - Video augmented by shearing: hello_2.mp4
# INFO - Video augmented by shearing: hello_3.mp4
# INFO - Video augmented by shearing: hello_4.mp4
# INFO - Video augmented by shearing: hello_5.mp4
# INFO - Video augmented by applying Gaussian Blur: hello_1.mp4
# INFO - Video augmented by applying Gaussian Blur: hello_2.mp4
# INFO - Video augmented by applying Gaussian Blur: hello_3.mp4
# INFO - Video augmented by applying Gaussian Blur: hello_4.mp4
# INFO - Video augmented by applying Gaussian Blur: hello_5.mp4

# %% [markdown]
# ## 2.5 Organization of files
#
# The above augmentation steps create a nested folder within and we will have to reorganize the files so that they are combined together into a single folder for efficient extraction of keypoints. We will move all the augmented files into the folder where the original files are located.
#
# We will use `hello` in the `train_data` folder as an example. The folder path for the original resized and cropped video files for `hello` are found in `'../videos/train_data/hello/cropped_videos/`. While the augmented video files are found in the nested folder '../videos/train_data/hello/cropped_videos/`videos_to_annotate`. Hence, we will move all the augmented video files into the `cropped_videos` where the unaltered videos are and delete the empty `videos_to_annotate` folder.

# %%
# create a function to move a single video file to the folder destination
def move_video(source_file_path, destination_directory):
    '''
    Moves a single video file to the specified destination directory.

    Args:
    source_file_path (str): The path to the source video file.
    destination_directory (str): The path to the destination directory where the video should be moved.
    '''
    # Ensure the destination directory exists
    os.makedirs(destination_directory, exist_ok=True)
    
    # Define the destination file path
    video_file = os.path.basename(source_file_path)
    destination_file_path = os.path.join(destination_directory, video_file)

    # Move the video file
    shutil.move(source_file_path, destination_file_path)
    # print(f'Moved {video_file} to {destination_directory}') # debug
    logging.info(f'Moved {video_file} to {destination_directory}') # write to logging file
    

# function to move the video files to the respective destination folder and delete the nested folder
def copy_to_annotate(label, train_test_val_type):
    GENERAL_PATH = '../videos/'
    SOURCE_PATH = os.path.join(GENERAL_PATH, train_test_val_type, 'output', label, 'videos_to_annotate')
    OUTPUT_DIR = os.path.join(GENERAL_PATH, train_test_val_type, 'output', label)

    # Ensure the output directory exists
    os.makedirs(OUTPUT_DIR, exist_ok=True)

    # Check if the source directory exists
    if os.path.exists(SOURCE_PATH) and os.path.isdir(SOURCE_PATH):
        # Iterate through each video file in the source directory
        for vid in os.listdir(SOURCE_PATH):
            VID_PATH = os.path.join(SOURCE_PATH, vid)
            if os.path.isfile(VID_PATH):  # Check if it is a file
                move_video(VID_PATH, OUTPUT_DIR)

        # Once all files have been moved, delete the source directory
        shutil.rmtree(SOURCE_PATH)
        print(f'Deleted directory {SOURCE_PATH}')
    else:
        print(f'Source directory {SOURCE_PATH} does not exist.')

    return 'All original resized video files have been moved and the source directory deleted'

# %%
# initiate the organization steps

folder_list = ['train_data', 'test_data', 'val_data']

for vid in first_three:
    for folder in folder_list:
        copy_to_annotate(vid, folder)
    print('-' * 30)
# Out:
# INFO - Moved please_darkened_1.mp4 to ../videos/train_data\output\please
# INFO - Moved please_darkened_10.mp4 to ../videos/train_data\output\please
# INFO - Moved please_darkened_11.mp4 to ../videos/train_data\output\please
# INFO - Moved please_darkened_12.mp4 to ../videos/train_data\output\please
# INFO - Moved please_darkened_13.mp4 to ../videos/train_data\output\please
# INFO - Moved please_darkened_14.mp4 to ../videos/train_data\output\please
# INFO - Moved please_darkened_15.mp4 to ../videos/train_data\output\please
# INFO - Moved please_darkened_16.mp4 to ../videos/train_data\output\please
# INFO - Moved please_darkened_17.mp4 to ../videos/train_data\output\please
# INFO - Moved please_darkened_18.mp4 to ../videos/train_data\output\please
# INFO - Moved please_darkened_19.mp4 to ../videos/train_data\output\please
# INFO - Moved please_darkened_2.mp4 to ../videos/train_data\output\please
# INFO - Moved please_darkened_20.mp4 to ../videos/train_data\output\please
# INFO - Moved please_darkened_21.mp4 to ../videos/train_data\output\please
# INFO - Moved please_darkened_22.mp4 to ../videos/train_data\output\please
# INFO - Moved please_darkened_23.mp4 to ../videos/train_data\output\please
# INFO - Moved please_darkened_24.mp4 to ../videos/train_data\output\please
# INFO - Moved please_darkened_25.mp4 to ../videos/train_data\output\please
# INFO - Moved please_darkened_26.mp4 to ../videos/train_data\output\please
# INFO - Moved please_darkened_27.mp4 to ../videos/train_data\output\please
# INFO - Moved please_darkened_28.mp4 to ../videos/train_data\output\please
# INFO - Moved please_darkened_29.mp4 to ../videos/train_data\output\please
# INFO - Moved please_darkened_3.mp4 to ../videos/train_data\output\please
# INFO - Moved please_darkened_4.mp4 to ../videos/train_data\output\please
# INFO - Moved please_darkened_5.mp4 to ../videos/train_data\output\please
# INFO - Moved please_darkened_6.mp4 to ../videos/train_data\output\please
# INFO - Moved please_darkened_7.mp4 to ../videos/train_data\output\please
# INFO - Moved please_darkened_8.mp4 to ../videos/train_data\output\please
# INFO - Moved please_darkened_9.mp4 to ../videos/train_data\output\please
# INFO - Moved please_decrease_contrast_1.mp4 to ../videos/train_data\output\please
# INFO - Moved please_decrease_contrast_10.mp4 to ../videos/train_data\output\please
# INFO - Moved please_decrease_contrast_11.mp4 to ../videos/train_data\output\please
# INFO - Moved please_decrease_contrast_12.mp4 to ../videos/train_data\output\please
# INFO - Moved please_decrease_contrast_13.mp4 to ../videos/train_data\output\please
# INFO - Moved please_decrease_contrast_14.mp4 to ../videos/train_data\output\please
# INFO - Moved please_decrease_contrast_15.mp4 to ../videos/train_data\output\please
# INFO - Moved please_decrease_contrast_16.mp4 to ../videos/train_data\output\please
# INFO - Moved please_decrease_contrast_17.mp4 to ../videos/train_data\output\please
# INFO - Moved please_decrease_contrast_18.mp4 to ../videos/train_data\output\please
# INFO - Moved please_decrease_contrast_19.mp4 to ../videos/train_data\output\please
# INFO - Moved please_decrease_contrast_2.mp4 to ../videos/train_data\output\please
# INFO - Moved please_decrease_contrast_20.mp4 to ../videos/train_data\output\please
# INFO - Moved please_decrease_contrast_21.mp4 to ../videos/train_data\output\please
# INFO - Moved please_decrease_contrast_22.mp4 to ../videos/train_data\output\please
# INFO - Moved please_decrease_contrast_23.mp4 to ../videos/train_data\output\please
# INFO - Moved please_decrease_contrast_24.mp4 to ../videos/train_data\output\please
# INFO - Moved please_decrease_contrast_25.mp4 to ../videos/train_data\output\please
# INFO - Moved please_decrease_contrast_26.mp4 to ../videos/train_data\output\please
# INFO - Moved please_decrease_contrast_27.mp4 to ../videos/train_data\output\please
# INFO - Moved please_decrease_contrast_28.mp4 to ../videos/train_data\output\please
# INFO - Moved please_decrease_contrast_29.mp4 to ../videos/train_data\output\please
# INFO - Moved please_decrease_contrast_3.mp4 to ../videos/train_data\output\please
# INFO - Moved please_decrease_contrast_4.mp4 to ../videos/train_data\output\please
# INFO - Moved please_decrease_contrast_5.mp4 to ../videos/train_data\output\please
# INFO - Moved please_decrease_contrast_6.mp4 to ../videos/train_data\output\please
# INFO - Moved please_decrease_contrast_7.mp4 to ../videos/train_data\output\please
# INFO - Moved please_decrease_contrast_8.mp4 to ../videos/train_data\output\please
# INFO - Moved please_decrease_contrast_9.mp4 to ../videos/train_data\output\please
# INFO - Moved please_flipped_1.mp4 to ../videos/train_data\output\please
# INFO - Moved please_flipped_10.mp4 to ../videos/train_data\output\please
# INFO - Moved please_flipped_11.mp4 to ../videos/train_data\output\please
# INFO - Moved please_flipped_12.mp4 to ../videos/train_data\output\please
# INFO - Moved please_flipped_13.mp4 to ../videos/train_data\output\please
# INFO - Moved please_flipped_14.mp4 to ../videos/train_data\output\please
# INFO - Moved please_flipped_15.mp4 to ../videos/train_data\output\please
# INFO - Moved please_flipped_16.mp4 to ../videos/train_data\output\please
# INFO - Moved please_flipped_17.mp4 to ../videos/train_data\output\please
# INFO - Moved please_flipped_18.mp4 to ../videos/train_data\output\please
# INFO - Moved please_flipped_19.mp4 to ../videos/train_data\output\please
# INFO - Moved please_flipped_2.mp4 to ../videos/train_data\output\please
# INFO - Moved please_flipped_20.mp4 to ../videos/train_data\output\please
# INFO - Moved please_flipped_21.mp4 to ../videos/train_data\output\please
# INFO - Moved please_flipped_22.mp4 to ../videos/train_data\output\please
# INFO - Moved please_flipped_23.mp4 to ../videos/train_data\output\please
# INFO - Moved please_flipped_24.mp4 to ../videos/train_data\output\please
# INFO - Moved please_flipped_25.mp4 to ../videos/train_data\output\please
# INFO - Moved please_flipped_26.mp4 to ../videos/train_data\output\please
# INFO - Moved please_flipped_27.mp4 to ../videos/train_data\output\please
# INFO - Moved please_flipped_28.mp4 to ../videos/train_data\output\please
# INFO - Moved please_flipped_29.mp4 to ../videos/train_data\output\please
# INFO - Moved please_flipped_3.mp4 to ../videos/train_data\output\please
# INFO - Moved please_flipped_4.mp4 to ../videos/train_data\output\please
# INFO - Moved please_flipped_5.mp4 to ../videos/train_data\output\please
# INFO - Moved please_flipped_6.mp4 to ../videos/train_data\output\please
# INFO - Moved please_flipped_7.mp4 to ../videos/train_data\output\please
# INFO - Moved please_flipped_8.mp4 to ../videos/train_data\output\please
# INFO - Moved please_flipped_9.mp4 to ../videos/train_data\output\please
# INFO - Moved please_Gblur_1.mp4 to ../videos/train_data\output\please
# INFO - Moved please_Gblur_10.mp4 to ../videos/train_data\output\please
# INFO - Moved please_Gblur_11.mp4 to ../videos/train_data\output\please
# INFO - Moved please_Gblur_12.mp4 to ../videos/train_data\output\please
# INFO - Moved please_Gblur_13.mp4 to ../videos/train_data\output\please
# INFO - Moved please_Gblur_14.mp4 to ../videos/train_data\output\please
# INFO - Moved please_Gblur_15.mp4 to ../videos/train_data\output\please
# INFO - Moved please_Gblur_16.mp4 to ../videos/train_data\output\please
# INFO - Moved please_Gblur_17.mp4 to ../videos/train_data\output\please
# INFO - Moved please_Gblur_18.mp4 to ../videos/train_data\output\please
# INFO - Moved please_Gblur_19.mp4 to ../videos/train_data\output\please
# INFO - Moved please_Gblur_2.mp4 to ../videos/train_data\output\please
# INFO - Moved please_Gblur_20.mp4 to ../videos/train_data\output\please
# INFO - Moved please_Gblur_21.mp4 to ../videos/train_data\output\please
# INFO - Moved please_Gblur_22.mp4 to ../videos/train_data\output\please
# INFO - Moved please_Gblur_23.mp4 to ../videos/train_data\output\please
# INFO - Moved please_Gblur_24.mp4 to ../videos/train_data\output\please
# INFO - Moved please_Gblur_25.mp4 to ../videos/train_data\output\please
# INFO - Moved please_Gblur_26.mp4 to ../videos/train_data\output\please
# INFO - Moved please_Gblur_27.mp4 to ../videos/train_data\output\please
# INFO - Moved please_Gblur_28.mp4 to ../videos/train_data\output\please
# INFO - Moved please_Gblur_29.mp4 to ../videos/train_data\output\please
# INFO - Moved please_Gblur_3.mp4 to ../videos/train_data\output\please
# INFO - Moved please_Gblur_4.mp4 to ../videos/train_data\output\please
# INFO - Moved please_Gblur_5.mp4 to ../videos/train_data\output\please
# INFO - Moved please_Gblur_6.mp4 to ../videos/train_data\output\please
# INFO - Moved please_Gblur_7.mp4 to ../videos/train_data\output\please
# INFO - Moved please_Gblur_8.mp4 to ../videos/train_data\output\please
# INFO - Moved please_Gblur_9.mp4 to ../videos/train_data\output\please
# INFO - Moved please_increase_contrast_1.mp4 to ../videos/train_data\output\please
# INFO - Moved please_increase_contrast_10.mp4 to ../videos/train_data\output\please
# INFO - Moved please_increase_contrast_11.mp4 to ../videos/train_data\output\please
# INFO - Moved please_increase_contrast_12.mp4 to ../videos/train_data\output\please
# INFO - Moved please_increase_contrast_13.mp4 to ../videos/train_data\output\please
# INFO - Moved please_increase_contrast_14.mp4 to ../videos/train_data\output\please
# INFO - Moved please_increase_contrast_15.mp4 to ../videos/train_data\output\please
# INFO - Moved please_increase_contrast_16.mp4 to ../videos/train_data\output\please
# INFO - Moved please_increase_contrast_17.mp4 to ../videos/train_data\output\please
# INFO - Moved please_increase_contrast_18.mp4 to ../videos/train_data\output\please
# INFO - Moved please_increase_contrast_19.mp4 to ../videos/train_data\output\please
# INFO - Moved please_increase_contrast_2.mp4 to ../videos/train_data\output\please
# INFO - Moved please_increase_contrast_20.mp4 to ../videos/train_data\output\please
# INFO - Moved please_increase_contrast_21.mp4 to ../videos/train_data\output\please
# INFO - Moved please_increase_contrast_22.mp4 to ../videos/train_data\output\please
# INFO - Moved please_increase_contrast_23.mp4 to ../videos/train_data\output\please
# INFO - Moved please_increase_contrast_24.mp4 to ../videos/train_data\output\please
# INFO - Moved please_increase_contrast_25.mp4 to ../videos/train_data\output\please
# INFO - Moved please_increase_contrast_26.mp4 to ../videos/train_data\output\please
# INFO - Moved please_increase_contrast_27.mp4 to ../videos/train_data\output\please
# INFO - Moved please_increase_contrast_28.mp4 to ../videos/train_data\output\please
# INFO - Moved please_increase_contrast_29.mp4 to ../videos/train_data\output\please
# INFO - Moved please_increase_contrast_3.mp4 to ../videos/train_data\output\please
# INFO - Moved please_increase_contrast_4.mp4 to ../videos/train_data\output\please
# INFO - Moved please_increase_contrast_5.mp4 to ../videos/train_data\output\please
# INFO - Moved please_increase_contrast_6.mp4 to ../videos/train_data\output\please
# INFO - Moved please_increase_contrast_7.mp4 to ../videos/train_data\output\please
# INFO - Moved please_increase_contrast_8.mp4 to ../videos/train_data\output\please
# INFO - Moved please_increase_contrast_9.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_negative_1.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_negative_10.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_negative_11.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_negative_12.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_negative_13.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_negative_14.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_negative_15.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_negative_16.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_negative_17.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_negative_18.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_negative_19.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_negative_2.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_negative_20.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_negative_21.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_negative_22.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_negative_23.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_negative_24.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_negative_25.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_negative_26.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_negative_27.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_negative_28.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_negative_29.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_negative_3.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_negative_4.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_negative_5.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_negative_6.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_negative_7.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_negative_8.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_negative_9.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_positive_1.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_positive_10.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_positive_11.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_positive_12.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_positive_13.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_positive_14.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_positive_15.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_positive_16.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_positive_17.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_positive_18.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_positive_19.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_positive_2.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_positive_20.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_positive_21.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_positive_22.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_positive_23.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_positive_24.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_positive_25.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_positive_26.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_positive_27.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_positive_28.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_positive_29.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_positive_3.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_positive_4.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_positive_5.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_positive_6.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_positive_7.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_positive_8.mp4 to ../videos/train_data\output\please
# INFO - Moved please_shear_positive_9.mp4 to ../videos/train_data\output\please
# INFO - Moved please_darkened_1.mp4 to ../videos/test_data\output\please
# INFO - Moved please_darkened_2.mp4 to ../videos/test_data\output\please
# INFO - Moved please_darkened_3.mp4 to ../videos/test_data\output\please
# INFO - Moved please_decrease_contrast_1.mp4 to ../videos/test_data\output\please
# INFO - Moved please_decrease_contrast_2.mp4 to ../videos/test_data\output\please
# INFO - Moved please_decrease_contrast_3.mp4 to ../videos/test_data\output\please
# INFO - Moved please_flipped_1.mp4 to ../videos/test_data\output\please
# INFO - Moved please_flipped_2.mp4 to ../videos/test_data\output\please
# INFO - Moved please_flipped_3.mp4 to ../videos/test_data\output\please
# INFO - Moved please_Gblur_1.mp4 to ../videos/test_data\output\please
# INFO - Moved please_Gblur_2.mp4 to ../videos/test_data\output\please
# INFO - Moved please_Gblur_3.mp4 to ../videos/test_data\output\please
# INFO - Moved please_increase_contrast_1.mp4 to ../videos/test_data\output\please
# INFO - Moved please_increase_contrast_2.mp4 to ../videos/test_data\output\please
# INFO - Moved please_increase_contrast_3.mp4 to ../videos/test_data\output\please
# INFO - Moved please_shear_negative_1.mp4 to ../videos/test_data\output\please
# INFO - Moved please_shear_negative_2.mp4 to ../videos/test_data\output\please
# INFO - Moved please_shear_negative_3.mp4 to ../videos/test_data\output\please
# INFO - Moved please_shear_positive_1.mp4 to ../videos/test_data\output\please
# INFO - Moved please_shear_positive_2.mp4 to ../videos/test_data\output\please
# INFO - Moved please_shear_positive_3.mp4 to ../videos/test_data\output\please
# INFO - Moved please_darkened_1.mp4 to ../videos/val_data\output\please
# INFO - Moved please_darkened_2.mp4 to ../videos/val_data\output\please
# INFO - Moved please_darkened_3.mp4 to ../videos/val_data\output\please
# INFO - Moved please_decrease_contrast_1.mp4 to ../videos/val_data\output\please
# INFO - Moved please_decrease_contrast_2.mp4 to ../videos/val_data\output\please
# INFO - Moved please_decrease_contrast_3.mp4 to ../videos/val_data\output\please
# INFO - Moved please_flipped_1.mp4 to ../videos/val_data\output\please
# INFO - Moved please_flipped_2.mp4 to ../videos/val_data\output\please
# INFO - Moved please_flipped_3.mp4 to ../videos/val_data\output\please
# INFO - Moved please_Gblur_1.mp4 to ../videos/val_data\output\please
# INFO - Moved please_Gblur_2.mp4 to ../videos/val_data\output\please
# INFO - Moved please_Gblur_3.mp4 to ../videos/val_data\output\please
# INFO - Moved please_increase_contrast_1.mp4 to ../videos/val_data\output\please
# INFO - Moved please_increase_contrast_2.mp4 to ../videos/val_data\output\please
# INFO - Moved please_increase_contrast_3.mp4 to ../videos/val_data\output\please
# INFO - Moved please_shear_negative_1.mp4 to ../videos/val_data\output\please
# INFO - Moved please_shear_negative_2.mp4 to ../videos/val_data\output\please
# INFO - Moved please_shear_negative_3.mp4 to ../videos/val_data\output\please
# INFO - Moved please_shear_positive_1.mp4 to ../videos/val_data\output\please
# INFO - Moved please_shear_positive_2.mp4 to ../videos/val_data\output\please
# INFO - Moved please_shear_positive_3.mp4 to ../videos/val_data\output\please
# INFO - Moved sorry_darkened_1.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_darkened_10.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_darkened_11.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_darkened_12.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_darkened_13.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_darkened_14.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_darkened_15.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_darkened_16.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_darkened_17.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_darkened_18.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_darkened_2.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_darkened_3.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_darkened_4.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_darkened_5.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_darkened_6.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_darkened_7.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_darkened_8.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_darkened_9.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_decrease_contrast_1.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_decrease_contrast_10.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_decrease_contrast_11.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_decrease_contrast_12.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_decrease_contrast_13.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_decrease_contrast_14.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_decrease_contrast_15.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_decrease_contrast_16.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_decrease_contrast_17.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_decrease_contrast_18.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_decrease_contrast_2.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_decrease_contrast_3.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_decrease_contrast_4.mp4 to ../videos/train_data\output\sorry
# Deleted directory ../videos/train_data\output\please\videos_to_annotate
# Deleted directory ../videos/test_data\output\please\videos_to_annotate
# Deleted directory ../videos/val_data\output\please\videos_to_annotate
# ------------------------------
# INFO - Moved sorry_decrease_contrast_5.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_decrease_contrast_6.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_decrease_contrast_7.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_decrease_contrast_8.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_decrease_contrast_9.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_flipped_1.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_flipped_10.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_flipped_11.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_flipped_12.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_flipped_13.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_flipped_14.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_flipped_15.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_flipped_16.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_flipped_17.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_flipped_18.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_flipped_2.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_flipped_3.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_flipped_4.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_flipped_5.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_flipped_6.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_flipped_7.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_flipped_8.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_flipped_9.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_Gblur_1.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_Gblur_10.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_Gblur_11.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_Gblur_12.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_Gblur_13.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_Gblur_14.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_Gblur_15.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_Gblur_16.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_Gblur_17.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_Gblur_18.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_Gblur_2.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_Gblur_3.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_Gblur_4.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_Gblur_5.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_Gblur_6.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_Gblur_7.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_Gblur_8.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_Gblur_9.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_increase_contrast_1.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_increase_contrast_10.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_increase_contrast_11.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_increase_contrast_12.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_increase_contrast_13.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_increase_contrast_14.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_increase_contrast_15.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_increase_contrast_16.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_increase_contrast_17.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_increase_contrast_18.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_increase_contrast_2.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_increase_contrast_3.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_increase_contrast_4.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_increase_contrast_5.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_increase_contrast_6.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_increase_contrast_7.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_increase_contrast_8.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_increase_contrast_9.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_shear_negative_1.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_shear_negative_10.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_shear_negative_11.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_shear_negative_12.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_shear_negative_13.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_shear_negative_14.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_shear_negative_15.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_shear_negative_16.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_shear_negative_17.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_shear_negative_18.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_shear_negative_2.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_shear_negative_3.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_shear_negative_4.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_shear_negative_5.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_shear_negative_6.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_shear_negative_7.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_shear_negative_8.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_shear_negative_9.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_shear_positive_1.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_shear_positive_10.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_shear_positive_11.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_shear_positive_12.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_shear_positive_13.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_shear_positive_14.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_shear_positive_15.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_shear_positive_16.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_shear_positive_17.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_shear_positive_18.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_shear_positive_2.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_shear_positive_3.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_shear_positive_4.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_shear_positive_5.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_shear_positive_6.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_shear_positive_7.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_shear_positive_8.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_shear_positive_9.mp4 to ../videos/train_data\output\sorry
# INFO - Moved sorry_darkened_1.mp4 to ../videos/test_data\output\sorry
# INFO - Moved sorry_decrease_contrast_1.mp4 to ../videos/test_data\output\sorry
# INFO - Moved sorry_flipped_1.mp4 to ../videos/test_data\output\sorry
# INFO - Moved sorry_Gblur_1.mp4 to ../videos/test_data\output\sorry
# INFO - Moved sorry_increase_contrast_1.mp4 to ../videos/test_data\output\sorry
# INFO - Moved sorry_shear_negative_1.mp4 to ../videos/test_data\output\sorry
# INFO - Moved sorry_shear_positive_1.mp4 to ../videos/test_data\output\sorry
# INFO - Moved sorry_darkened_1.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_darkened_10.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_darkened_2.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_darkened_3.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_darkened_4.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_darkened_5.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_darkened_6.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_darkened_7.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_darkened_8.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_darkened_9.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_decrease_contrast_1.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_decrease_contrast_10.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_decrease_contrast_2.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_decrease_contrast_3.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_decrease_contrast_4.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_decrease_contrast_5.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_decrease_contrast_6.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_decrease_contrast_7.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_decrease_contrast_8.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_decrease_contrast_9.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_flipped_1.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_flipped_10.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_flipped_2.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_flipped_3.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_flipped_4.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_flipped_5.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_flipped_6.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_flipped_7.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_flipped_8.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_flipped_9.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_Gblur_1.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_Gblur_10.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_Gblur_2.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_Gblur_3.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_Gblur_4.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_Gblur_5.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_Gblur_6.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_Gblur_7.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_Gblur_8.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_Gblur_9.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_increase_contrast_1.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_increase_contrast_10.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_increase_contrast_2.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_increase_contrast_3.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_increase_contrast_4.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_increase_contrast_5.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_increase_contrast_6.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_increase_contrast_7.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_increase_contrast_8.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_increase_contrast_9.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_shear_negative_1.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_shear_negative_10.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_shear_negative_2.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_shear_negative_3.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_shear_negative_4.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_shear_negative_5.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_shear_negative_6.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_shear_negative_7.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_shear_negative_8.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_shear_negative_9.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_shear_positive_1.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_shear_positive_10.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_shear_positive_2.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_shear_positive_3.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_shear_positive_4.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_shear_positive_5.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_shear_positive_6.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_shear_positive_7.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_shear_positive_8.mp4 to ../videos/val_data\output\sorry
# INFO - Moved sorry_shear_positive_9.mp4 to ../videos/val_data\output\sorry
# INFO - Moved hello_darkened_1.mp4 to ../videos/train_data\output\hello
# Deleted directory ../videos/train_data\output\sorry\videos_to_annotate
# Deleted directory ../videos/test_data\output\sorry\videos_to_annotate
# Deleted directory ../videos/val_data\output\sorry\videos_to_annotate
# ------------------------------
# INFO - Moved hello_darkened_10.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_darkened_11.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_darkened_12.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_darkened_13.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_darkened_14.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_darkened_15.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_darkened_16.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_darkened_17.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_darkened_2.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_darkened_3.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_darkened_4.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_darkened_5.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_darkened_6.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_darkened_7.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_darkened_8.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_darkened_9.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_decrease_contrast_1.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_decrease_contrast_10.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_decrease_contrast_11.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_decrease_contrast_12.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_decrease_contrast_13.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_decrease_contrast_14.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_decrease_contrast_15.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_decrease_contrast_16.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_decrease_contrast_17.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_decrease_contrast_2.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_decrease_contrast_3.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_decrease_contrast_4.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_decrease_contrast_5.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_decrease_contrast_6.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_decrease_contrast_7.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_decrease_contrast_8.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_decrease_contrast_9.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_flipped_1.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_flipped_10.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_flipped_11.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_flipped_12.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_flipped_13.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_flipped_14.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_flipped_15.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_flipped_16.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_flipped_17.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_flipped_2.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_flipped_3.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_flipped_4.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_flipped_5.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_flipped_6.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_flipped_7.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_flipped_8.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_flipped_9.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_Gblur_1.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_Gblur_10.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_Gblur_11.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_Gblur_12.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_Gblur_13.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_Gblur_14.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_Gblur_15.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_Gblur_16.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_Gblur_17.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_Gblur_2.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_Gblur_3.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_Gblur_4.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_Gblur_5.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_Gblur_6.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_Gblur_7.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_Gblur_8.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_Gblur_9.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_increase_contrast_1.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_increase_contrast_10.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_increase_contrast_11.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_increase_contrast_12.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_increase_contrast_13.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_increase_contrast_14.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_increase_contrast_15.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_increase_contrast_16.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_increase_contrast_17.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_increase_contrast_2.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_increase_contrast_3.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_increase_contrast_4.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_increase_contrast_5.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_increase_contrast_6.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_increase_contrast_7.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_increase_contrast_8.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_increase_contrast_9.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_shear_negative_1.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_shear_negative_10.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_shear_negative_11.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_shear_negative_12.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_shear_negative_13.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_shear_negative_14.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_shear_negative_15.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_shear_negative_16.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_shear_negative_17.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_shear_negative_2.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_shear_negative_3.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_shear_negative_4.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_shear_negative_5.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_shear_negative_6.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_shear_negative_7.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_shear_negative_8.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_shear_negative_9.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_shear_positive_1.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_shear_positive_10.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_shear_positive_11.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_shear_positive_12.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_shear_positive_13.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_shear_positive_14.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_shear_positive_15.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_shear_positive_16.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_shear_positive_17.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_shear_positive_2.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_shear_positive_3.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_shear_positive_4.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_shear_positive_5.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_shear_positive_6.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_shear_positive_7.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_shear_positive_8.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_shear_positive_9.mp4 to ../videos/train_data\output\hello
# INFO - Moved hello_darkened_1.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_darkened_10.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_darkened_2.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_darkened_3.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_darkened_4.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_darkened_5.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_darkened_6.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_darkened_7.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_darkened_8.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_darkened_9.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_decrease_contrast_1.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_decrease_contrast_10.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_decrease_contrast_2.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_decrease_contrast_3.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_decrease_contrast_4.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_decrease_contrast_5.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_decrease_contrast_6.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_decrease_contrast_7.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_decrease_contrast_8.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_decrease_contrast_9.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_flipped_1.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_flipped_10.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_flipped_2.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_flipped_3.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_flipped_4.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_flipped_5.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_flipped_6.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_flipped_7.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_flipped_8.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_flipped_9.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_Gblur_1.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_Gblur_10.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_Gblur_2.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_Gblur_3.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_Gblur_4.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_Gblur_5.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_Gblur_6.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_Gblur_7.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_Gblur_8.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_Gblur_9.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_increase_contrast_1.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_increase_contrast_10.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_increase_contrast_2.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_increase_contrast_3.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_increase_contrast_4.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_increase_contrast_5.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_increase_contrast_6.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_increase_contrast_7.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_increase_contrast_8.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_increase_contrast_9.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_shear_negative_1.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_shear_negative_10.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_shear_negative_2.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_shear_negative_3.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_shear_negative_4.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_shear_negative_5.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_shear_negative_6.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_shear_negative_7.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_shear_negative_8.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_shear_negative_9.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_shear_positive_1.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_shear_positive_10.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_shear_positive_2.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_shear_positive_3.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_shear_positive_4.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_shear_positive_5.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_shear_positive_6.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_shear_positive_7.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_shear_positive_8.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_shear_positive_9.mp4 to ../videos/test_data\output\hello
# INFO - Moved hello_darkened_1.mp4 to ../videos/val_data\output\hello
# INFO - Moved hello_darkened_2.mp4 to ../videos/val_data\output\hello
# INFO - Moved hello_darkened_3.mp4 to ../videos/val_data\output\hello
# INFO - Moved hello_darkened_4.mp4 to ../videos/val_data\output\hello
# INFO - Moved hello_darkened_5.mp4 to ../videos/val_data\output\hello
# INFO - Moved hello_decrease_contrast_1.mp4 to ../videos/val_data\output\hello
# INFO - Moved hello_decrease_contrast_2.mp4 to ../videos/val_data\output\hello
# INFO - Moved hello_decrease_contrast_3.mp4 to ../videos/val_data\output\hello
# INFO - Moved hello_decrease_contrast_4.mp4 to ../videos/val_data\output\hello
# INFO - Moved hello_decrease_contrast_5.mp4 to ../videos/val_data\output\hello
# INFO - Moved hello_flipped_1.mp4 to ../videos/val_data\output\hello
# INFO - Moved hello_flipped_2.mp4 to ../videos/val_data\output\hello
# INFO - Moved hello_flipped_3.mp4 to ../videos/val_data\output\hello
# INFO - Moved hello_flipped_4.mp4 to ../videos/val_data\output\hello
# INFO - Moved hello_flipped_5.mp4 to ../videos/val_data\output\hello
# INFO - Moved hello_Gblur_1.mp4 to ../videos/val_data\output\hello
# INFO - Moved hello_Gblur_2.mp4 to ../videos/val_data\output\hello
# INFO - Moved hello_Gblur_3.mp4 to ../videos/val_data\output\hello
# INFO - Moved hello_Gblur_4.mp4 to ../videos/val_data\output\hello
# INFO - Moved hello_Gblur_5.mp4 to ../videos/val_data\output\hello
# INFO - Moved hello_increase_contrast_1.mp4 to ../videos/val_data\output\hello
# INFO - Moved hello_increase_contrast_2.mp4 to ../videos/val_data\output\hello
# INFO - Moved hello_increase_contrast_3.mp4 to ../videos/val_data\output\hello
# INFO - Moved hello_increase_contrast_4.mp4 to ../videos/val_data\output\hello
# INFO - Moved hello_increase_contrast_5.mp4 to ../videos/val_data\output\hello
# INFO - Moved hello_shear_negative_1.mp4 to ../videos/val_data\output\hello
# INFO - Moved hello_shear_negative_2.mp4 to ../videos/val_data\output\hello
# INFO - Moved hello_shear_negative_3.mp4 to ../videos/val_data\output\hello
# Deleted directory ../videos/train_data\output\hello\videos_to_annotate
# Deleted directory ../videos/test_data\output\hello\videos_to_annotate
# INFO - Moved hello_shear_negative_4.mp4 to ../videos/val_data\output\hello
# INFO - Moved hello_shear_negative_5.mp4 to ../videos/val_data\output\hello
# INFO - Moved hello_shear_positive_1.mp4 to ../videos/val_data\output\hello
# INFO - Moved hello_shear_positive_2.mp4 to ../videos/val_data\output\hello
# INFO - Moved hello_shear_positive_3.mp4 to ../videos/val_data\output\hello
# INFO - Moved hello_shear_positive_4.mp4 to ../videos/val_data\output\hello
# INFO - Moved hello_shear_positive_5.mp4 to ../videos/val_data\output\hello
# Deleted directory ../videos/val_data\output\hello\videos_to_annotate
# ------------------------------
